# %% [markdown]
# ### Importing Data and Necessary libraries

# %%
import pandas as pd
import sqlite3
import csv

# %% [markdown]
# ### Importing csv files using Python

# %%
# Importing and converting cvs data files into dataframes  
df1 = pd.read_csv('HRData_Diversity.csv')
df2 = pd.read_csv('HRData_Employees.csv')
df3 = pd.read_csv('HRData_Manager.csv')
df4 = pd.read_csv('HRData_Positions.csv')

# %%
df5 = pd.read_csv('HRData_Positions.csv')

# %%
# Connecting to database 
conn = sqlite3.connect('hr_data_databasee.db')

# %%
# Adding dataframes to SQL database to use for analysis
df1.to_sql('HR_Diversity', conn, index=False,)
df2.to_sql('HR_Employees', conn, index=False)
df3.to_sql('HR_Manager', conn, index=False)
df4.to_sql('HR_Positions', conn, index=False)
# Out:
# 29

# %%
# Load the SQL extension to execute SQL commands in this notebook cell
# %load_ext sql

# %%
# Connect to the SQLite database named 'hr_database.db'
# %sql sqlite:///hr_data_databasee.db

# %% [markdown]
# ### Exploring the Data in our Database
# - Understand the schema of our four tables
# - Identify Primary and foreign keys in our tables

# %%
# %%sql
#
# -- Retrieve the names of tables in the SQLite database
# SELECT name AS hr_database_tables
# FROM sqlite_master
# WHERE type = 'table';
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('HR_Diversity',), ('HR_Employees',), ('HR_Manager',), ('HR_Positions',)]

# %%
# %%sql
#
# -- Show the schema of the table HR_Employees
# PRAGMA table_info(HR_Employees);
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [(0, 'Employee_Name', 'TEXT', 0, None, 0),
#  (1, 'EmpID', 'INTEGER', 0, None, 0),
#  (2, 'DeptID', 'INTEGER', 0, None, 0),
#  (3, 'Salary', 'INTEGER', 0, None, 0),
#  (4, 'PositionID', 'INTEGER', 0, None, 0),
#  (5, 'State', 'TEXT', 0, None, 0),
#  (6, 'DOB', 'TEXT', 0, None, 0),
#  (7, 'MaritalDesc', 'TEXT', 0, None, 0),
#  (8, 'DateofHire', 'TEXT', 0, None, 0),
#  (9, 'DateofTermination', 'TEXT', 0, None, 0),
#  (10, 'ManagerID', 'REAL', 0, None, 0),
#  (11, 'Department', 'TEXT', 0, None, 0),
#  (12, 'RecruitmentSource', 'TEXT', 0, None, 0),
#  (13, 'PerformanceScore', 'TEXT', 0, None, 0),
#  (14, 'EngagementSurvey', 'REAL', 0, None, 0),
#  (15, 'EmpSatisfaction', 'INTEGER', 0, None, 0),
#  (16, 'SpecialProjectsCount', 'INTEGER', 0, None, 0),
#  (17, 'Absences', 'INTEGER', 0, None, 0)]

# %%
# %%sql
#
# -- Show the schema of the table HR_Positions
# PRAGMA table_info(HR_Positions);
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [(0, 'PositionID', 'INTEGER', 0, None, 0), (1, 'Position', 'TEXT', 0, None, 0)]

# %%
# %%sql
#
# -- Show the schema of the table
# PRAGMA table_info(HR_Manager);
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [(0, 'EmpID', 'INTEGER', 0, None, 0),
#  (1, 'ManagerName', 'TEXT', 0, None, 0),
#  (2, 'ManagerID', 'REAL', 0, None, 0)]

# %%
# %%sql
#
# -- Show the schema of the table
# PRAGMA table_info(HR_Diversity);
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [(0, 'EmpID', 'INTEGER', 0, None, 0),
#  (1, 'Sex', 'TEXT', 0, None, 0),
#  (2, 'FromDiversityJobFairID', 'TEXT', 0, None, 0),
#  (3, 'HispanicLatino', 'TEXT', 0, None, 0),
#  (4, 'RaceDesc', 'TEXT', 0, None, 0)]

# %% [markdown]
# ### Data Cleaning - Create a new table named HR_Dataset by combining data from multiple tables

# %%
# %%sql
#
# -- Create a new table named HR_Dataset by combining data from multiple tables
# CREATE TABLE HR_Dataset AS
#
# SELECT *
# FROM HR_Employees e
# inner JOIN HR_Positions p ON e.positionID = p.positionID
# inner JOIN HR_Manager m on e.empid = m.empid
# inner JOIN HR_Diversity d on e.empid = d.empid;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# []

# %%
# %%sql
# --
# Select * from HR_Dataset limit 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 19, 'Production Technician I', 10026, 'Michael Albert', 22.0, 10026, 'M ', 'No', 'No', 'White')]

# %% [markdown]
# ### Ensuring new HR_Dataset has been added to database

# %%
# %%sql
#
# -- Retrieve the names of tables in the SQLite database
# SELECT name AS hr_database_tables
# FROM sqlite_master
# WHERE type = 'table';
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('HR_Diversity',),
#  ('HR_Employees',),
#  ('HR_Manager',),
#  ('HR_Positions',),
#  ('HR_Dataset',)]

# %% [markdown]
# ### Data Cleaning - Dropping Duplicate Columns from HR_Dataset table
# - Remove Redundant Columns from HR_Dataset Table that were added when joining the 4 tables in the database

# %%
# %%sql
#
# -- Remove the column 'positionid:1' from the HR_Dataset table
# ALTER TABLE HR_Dataset
# DROP COLUMN 'positionid:1';
#
# -- Remove the column 'empid:1' from the HR_Dataset table
# ALTER TABLE HR_Dataset
# DROP COLUMN 'empid:1';
#
# -- Remove the column 'managerid:1' from the HR_Dataset table
# ALTER TABLE HR_Dataset
# DROP COLUMN 'managerid:1';
#
# -- Remove the column 'empid:2' from the HR_Dataset table
# ALTER TABLE HR_Dataset
# DROP COLUMN 'empid:2';
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# -- Display the modified table
# select * from hr_dataset limit 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White')]

# %% [markdown]
# ### Data Cleaning - Changing Data Types
#
# - Updating data type from text to date for DOB, DateofHire, and DateofTermination columns

# %%
# %%sql
#
# -- Add a new column 'date_DOB' to the table and update column to a date data type
# ALTER TABLE HR_Dataset ADD COLUMN date_DOB date;
#
# UPDATE HR_Dataset
# SET date_DOB = strftime('%Y-%m-%d', DOB);
#
#
# -- Add a new column 'date_hired' to the table and update column to a date data type
# ALTER TABLE HR_Dataset ADD COLUMN date_hired date;
#
# UPDATE HR_Dataset
# SET date_hired = strftime('%Y-%m-%d', dateofhire);
#
#
# -- Add a new column 'date_term' to the table and update column to a date data type
# ALTER TABLE HR_Dataset ADD COLUMN date_term date;
#
# UPDATE HR_Dataset
# SET date_term = strftime('%Y-%m-%d', dateoftermination);
#
#
# -- Display the modified table with three added columns
# SELECT * FROM HR_Dataset
#
# LIMIT 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# 311 rows affected.
# Done.
# 311 rows affected.
# Done.
# 311 rows affected.
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', None)]

# %% [markdown]
# ### Data Manipulation - Replacing Null values from date of termination
# - Replacing all Null values from the date_term column as current date to create a column for display employee tenure

# %%
# %%sql
#
# UPDATE hr_dataset
#
# SET date_term = CURRENT_DATE
# WHERE date_term IS NULL;
# Out:
#  * sqlite:///hr_data_databasee.db
# 207 rows affected.
# []

# %%
# %%sql
#
# -- Display the modified table
# SELECT * FROM HR_Dataset LIMIT 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', '2023-09-21')]

# %% [markdown]
# ### Data Manipulation - Adding Employee Tenure Column

# %%
# %%sql
#
# ALTER TABLE HR_Dataset
# ADD COLUMN Tenure INTEGER;
#
# UPDATE HR_Dataset
# SET Tenure = CAST((julianday(date_term) - julianday(date_hired)) / 365.25 AS INTEGER);
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# 311 rows affected.
# []

# %%
# %%sql
#
# -- Display the modified table
# SELECT * FROM HR_Dataset LIMIT 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', '2023-09-21', 12)]

# %% [markdown]
# ### Data Manipulation
# - Added a new column 'Married_id' to the HR_Employees table
# - Update 'Married_id' values based on 'MaritalDesc' values

# %%
# %%sql
#
# ALTER TABLE HR_Dataset
# ADD COLUMN Married_id INTEGER;
#
# UPDATE HR_Dataset
# SET Married_id = CASE
#     WHEN MaritalDesc = 'Single' THEN 1
#     WHEN MaritalDesc = 'Widowed' THEN 1
#     WHEN MaritalDesc = 'Divorced' THEN 1
#     WHEN MaritalDesc = 'Married' THEN 0
#     ELSE NULL
# END;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# 311 rows affected.
# []

# %%
# %%sql
#
# -- Display the modified table
# SELECT * FROM HR_Dataset LIMIT 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', '2023-09-21', 12, 1)]

# %% [markdown]
# ### Data Manipulation
# - Added a new column 'PerfScore_ID' to the HR_Employees table
# - Update 'PerfScore_ID' values based on 'PerformanceScore' values

# %%
# %%sql
#
# ALTER TABLE HR_Dataset
# ADD COLUMN PerfScore_ID INTEGER;
#
# UPDATE HR_Dataset
# SET PerfScore_ID = CASE
#     WHEN PerformanceScore = 'Exceeds' THEN 4
#     WHEN PerformanceScore = 'Fully Meets' THEN 3
#     WHEN PerformanceScore = 'Needs Improvement' THEN 2
#     WHEN PerformanceScore = 'PIP' THEN 1
#     ELSE NULL
# END;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# 311 rows affected.
# []

# %%
# %%sql
#
# -- Display the modified table
# SELECT * FROM HR_Dataset LIMIT 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', '2023-09-21', 12, 1, 4)]

# %% [markdown]
# ### Data Manipulation
# - Added a new column 'DiversityJobFairScore' to the HR_Dataset table
# - Updated score values as 1 if employees were hired in a Diversity Job Fair and 0 if not

# %%
# %%sql
#
# ALTER TABLE HR_Dataset
# ADD COLUMN DiversityJobFairScore INTEGER;
#
# UPDATE HR_Dataset
# SET DiversityJobFairScore = CASE
#     WHEN FromDiversityJobFairID = 'Yes' THEN 1
#     ELSE 0
# END;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# 311 rows affected.
# []

# %%
# %%sql
#
# -- Display the modified table
# SELECT * FROM HR_Dataset LIMIT 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', '2023-09-21', 12, 1, 4, 0)]

# %% [markdown]
# ### Data Manipulation
# - Added a new column 'Date_Term' to the HR_Dataset table
# - Update values based on 'dateoftermination' column, 1 if employee had a termination date and 0 if date was Null

# %%
# %%sql
#
# UPDATE HR_Dataset
# SET date_term = CASE
#     WHEN dateoftermination IS NULL THEN 0
#     ELSE 1
# END;
# Out:
#  * sqlite:///hr_data_databasee.db
# 311 rows affected.
# []

# %%
# %%sql
#
# -- Display the modified table
# SELECT * FROM HR_Dataset LIMIT 1;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', 0, 12, 1, 4, 0)]

# %% [markdown]
# ### Export clean HR_Dataset table as a CVS file

# %%
# Query the hr_dataset table using the %sql magic command
result = %sql SELECT * FROM hr_dataset

# Convert the result to a DataFrame
df = result.DataFrame()

# Specify the CSV file path
csv_file_path = 'hr_dataset.csv'

# Export the DataFrame to a CSV file
df.to_csv(csv_file_path, index=False)
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.

# %%
# %%sql
#
# --CREATE TABLE HR_Dataset AS
#
# SELECT *
# FROM hr_dataset;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# [('Adinolfi, Wilson  K', 10026, 5, 62506, 19, 'MA', '1983-07-10', 'Single', '2011-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-07-10', '2011-07-05', 0, 12, 1, 4, 0),
#  ('Ait Sidi, Karthikeyan   ', 10084, 3, 104437, 27, 'MA', '1975-05-05', 'Married', '2015-03-30', '2016-06-16', 4.0, 'IT/IS', 'Indeed', 'Fully Meets', 4.96, 3, 6, 17, 'Sr. DBA', 'Simon Roup', 'M ', 'No', 'No', 'White', '1975-05-05', '2015-03-30', 1, 1, 0, 3, 0),
#  ('Akinkuolie, Sarah', 10196, 5, 64955, 20, 'MA', '1988-09-19', 'Married', '2011-07-05', '2012-09-24', 20.0, 'Production       ', 'LinkedIn', 'Fully Meets', 3.02, 3, 0, 3, 'Production Technician II', 'Kissy Sullivan', 'F', 'No', 'No', 'White', '1988-09-19', '2011-07-05', 1, 1, 0, 3, 0),
#  ('Alagbe,Trina', 10088, 5, 64991, 19, 'MA', '1988-09-27', 'Married', '2008-01-07', None, 16.0, 'Production       ', 'Indeed', 'Fully Meets', 4.84, 5, 0, 15, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1988-09-27', '2008-01-07', 0, 15, 0, 3, 0),
#  ('Anderson, Carol ', 10069, 5, 50825, 19, 'MA', '1989-09-08', 'Divorced', '2011-07-11', '2016-09-06', 39.0, 'Production       ', 'Google Search', 'Fully Meets', 5.0, 4, 0, 2, 'Production Technician I', 'Webster Butler', 'F', 'No', 'No', 'White', '1989-09-08', '2011-07-11', 1, 5, 1, 3, 0),
#  ('Anderson, Linda  ', 10002, 5, 57568, 19, 'MA', '1977-05-22', 'Single', '2012-01-09', None, 11.0, 'Production       ', 'LinkedIn', 'Exceeds', 5.0, 5, 0, 15, 'Production Technician I', 'Amy Dunn', 'F', 'No', 'No', 'White', '1977-05-22', '2012-01-09', 0, 11, 1, 4, 0),
#  ('Andreola, Colby', 10194, 4, 95660, 24, 'MA', '1979-05-24', 'Single', '2014-11-10', None, 10.0, 'Software Engineering', 'LinkedIn', 'Fully Meets', 3.04, 3, 4, 19, 'Software Engineer', 'Alex Sweetwater', 'F', 'No', 'No', 'White', '1979-05-24', '2014-11-10', 0, 8, 1, 3, 0),
#  ('Athwal, Sam', 10062, 5, 59365, 19, 'MA', '1983-02-18', 'Widowed', '2013-09-30', None, 19.0, 'Production       ', 'Employee Referral', 'Fully Meets', 5.0, 4, 0, 19, 'Production Technician I', 'Ketsia Liebig', 'M ', 'No', 'No', 'White', '1983-02-18', '2013-09-30', 0, 9, 1, 3, 0),
#  ('Bachiochi, Linda', 10114, 5, 47837, 19, 'MA', '1970-02-11', 'Single', '2009-07-06', None, 12.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.46, 3, 0, 4, 'Production Technician I', 'Brannon Miller', 'F', 'Yes', 'No', 'Black or African American', '1970-02-11', '2009-07-06', 0, 14, 1, 3, 1),
#  ('Bacong, Alejandro ', 10250, 3, 50178, 14, 'MA', '1988-01-07', 'Divorced', '2015-01-05', None, 7.0, 'IT/IS', 'Indeed', 'Fully Meets', 5.0, 5, 6, 16, 'IT Support', 'Peter Monroe', 'M ', 'No', 'No', 'White', '1988-01-07', '2015-01-05', 0, 8, 1, 3, 0),
#  ('Baczenski, Rachael  ', 10252, 5, 54670, 19, 'MA', '1974-01-12', 'Married', '2011-01-10', '2017-01-12', 14.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.2, 4, 0, 12, 'Production Technician I', 'David Stanley', 'F', 'Yes', 'Yes', 'Black or African American', '1974-01-12', '2011-01-10', 1, 6, 0, 3, 1),
#  ('Barbara, Thomas', 10242, 5, 47211, 19, 'MA', '1974-02-21', 'Married', '2012-04-02', '2016-09-19', 20.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.2, 3, 0, 15, 'Production Technician I', 'Kissy Sullivan', 'M ', 'Yes', 'Yes', 'Black or African American', '1974-02-21', '2012-04-02', 1, 4, 0, 3, 1),
#  ('Barbossa, Hector', 10012, 3, 92328, 9, 'TX', '1988-07-04', 'Divorced', '2014-11-10', None, 4.0, 'IT/IS', 'Diversity Job Fair', 'Exceeds', 4.28, 4, 5, 9, 'Data Analyst', 'Simon Roup', 'M ', 'Yes', 'No', 'Black or African American', '1988-07-04', '2014-11-10', 0, 8, 1, 4, 1),
#  ('Barone, Francesco  A', 10265, 5, 58709, 19, 'MA', '1983-07-20', 'Single', '2012-02-20', None, 18.0, 'Production       ', 'Google Search', 'Fully Meets', 4.6, 4, 0, 7, 'Production Technician I', 'Kelley Spirea', 'M ', 'No', 'No', 'Two or more races', '1983-07-20', '2012-02-20', 0, 11, 1, 3, 0),
#  ('Barton, Nader', 10066, 5, 52505, 19, 'MA', '1977-07-15', 'Divorced', '2012-09-24', '2017-04-06', 22.0, 'Production       ', 'On-line Web application', 'Fully Meets', 5.0, 5, 0, 1, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1977-07-15', '2012-09-24', 1, 4, 1, 3, 0),
#  ('Bates, Norman', 10061, 5, 57834, 19, 'MA', '1981-10-18', 'Single', '2011-02-21', '2017-08-04', 18.0, 'Production       ', 'Google Search', 'Fully Meets', 5.0, 4, 0, 20, 'Production Technician I', 'Kelley Spirea', 'M ', 'No', 'No', 'White', '1981-10-18', '2011-02-21', 1, 6, 1, 3, 0),
#  ('Beak, Kimberly  ', 10023, 5, 70131, 20, 'MA', '1966-04-17', 'Married', '2016-07-21', None, 18.0, 'Production       ', 'Employee Referral', 'Exceeds', 4.4, 3, 0, 16, 'Production Technician II', 'Kelley Spirea', 'F', 'No', 'No', 'White', '1966-04-17', '2016-07-21', 0, 7, 0, 4, 0),
#  ('Beatrice, Courtney ', 10055, 5, 59026, 19, 'MA', '1970-10-27', 'Single', '2011-04-04', None, 16.0, 'Production       ', 'Google Search', 'Fully Meets', 5.0, 5, 0, 12, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1970-10-27', '2011-04-04', 0, 12, 1, 3, 0),
#  ('Becker, Renee', 10245, 3, 110000, 8, 'MA', '1986-04-04', 'Single', '2014-07-07', '2015-09-12', 4.0, 'IT/IS', 'Google Search', 'Fully Meets', 4.5, 4, 5, 8, 'Database Administrator', 'Simon Roup', 'F', 'No', 'Yes', 'White', '1986-04-04', '2014-07-07', 1, 1, 1, 3, 0),
#  ('Becker, Scott', 10277, 5, 53250, 19, 'MA', '1979-04-06', 'Single', '2013-07-08', None, None, 'Production       ', 'LinkedIn', 'Fully Meets', 4.2, 4, 0, 13, 'Production Technician I', 'Webster Butler', 'M ', 'No', 'No', 'Asian', '1979-04-06', '2013-07-08', 0, 10, 1, 3, 0),
#  ('Bernstein, Sean', 10046, 5, 51044, 19, 'MA', '1970-12-22', 'Single', '2012-04-02', None, 11.0, 'Production       ', 'Google Search', 'Fully Meets', 5.0, 3, 0, 13, 'Production Technician I', 'Amy Dunn', 'M ', 'No', 'Yes', 'White', '1970-12-22', '2012-04-02', 0, 11, 1, 3, 0),
#  ('Biden, Lowan  M', 10226, 5, 64919, 19, 'MA', '1958-12-27', 'Divorced', '2013-08-19', None, 19.0, 'Production       ', 'Indeed', 'Fully Meets', 4.2, 3, 0, 2, 'Production Technician I', 'Ketsia Liebig', 'F', 'No', 'No', 'Asian', '1958-12-27', '2013-08-19', 0, 10, 1, 3, 0),
#  ('Billis, Helen', 10003, 5, 62910, 19, 'MA', '1989-09-01', 'Married', '2014-07-07', None, 12.0, 'Production       ', 'Indeed', 'Exceeds', 5.0, 3, 0, 19, 'Production Technician I', 'Brannon Miller', 'F', 'No', 'No', 'White', '1989-09-01', '2014-07-07', 0, 9, 0, 4, 0),
#  ('Blount, Dianna', 10294, 5, 66441, 20, 'MA', '1990-09-21', 'Single', '2011-04-04', None, 22.0, 'Production       ', 'CareerBuilder', 'Needs Improvement', 2.0, 3, 0, 3, 'Production Technician II', 'Michael Albert', 'F', 'No', 'No', 'White', '1990-09-21', '2011-04-04', 0, 12, 1, 2, 0),
#  ('Bondwell, Betsy', 10267, 5, 57815, 20, 'MA', '1967-01-16', 'Single', '2011-01-10', '2014-04-04', 16.0, 'Production       ', 'Google Search', 'Fully Meets', 4.8, 5, 0, 5, 'Production Technician II', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1967-01-16', '2011-01-10', 1, 3, 1, 3, 0),
#  ('Booth, Frank', 10199, 3, 103613, 30, 'CT', '1964-07-30', 'Single', '2014-02-17', '2016-02-19', 4.0, 'IT/IS', 'LinkedIn', 'Fully Meets', 3.5, 5, 7, 2, 'Enterprise Architect', 'Simon Roup', 'M ', 'No', 'No', 'Black or African American', '1964-07-30', '2014-02-17', 1, 2, 1, 3, 0),
#  ('Boutwell, Bonalyn', 10081, 1, 106367, 26, 'MA', '1987-04-04', 'Married', '2015-02-16', None, 3.0, 'Admin Offices', 'Diversity Job Fair', 'Fully Meets', 5.0, 4, 3, 4, 'Sr. Accountant', 'Brandon R. LeBlanc', 'F', 'Yes', 'No', 'Black or African American', '1987-04-04', '2015-02-16', 0, 8, 0, 3, 1),
#  ('Bozzi, Charles', 10175, 5, 74312, 18, 'MA', '1970-03-10', 'Single', '2013-09-30', '2014-08-07', 2.0, 'Production       ', 'Indeed', 'Fully Meets', 3.39, 3, 0, 14, 'Production Manager', 'Janet King', 'M ', 'No', 'No', 'Asian', '1970-03-10', '2013-09-30', 1, 0, 1, 3, 0),
#  ('Brill, Donna', 10177, 5, 53492, 19, 'MA', '1990-08-24', 'Married', '2012-04-02', '2013-06-15', 14.0, 'Production       ', 'Google Search', 'Fully Meets', 3.35, 4, 0, 6, 'Production Technician I', 'David Stanley', 'F', 'No', 'No', 'White', '1990-08-24', '2012-04-02', 1, 1, 0, 3, 0),
#  ('Brown, Mia', 10238, 1, 63000, 1, 'MA', '1987-11-24', 'Married', '2008-10-27', None, 1.0, 'Admin Offices', 'Diversity Job Fair', 'Fully Meets', 4.5, 2, 6, 14, 'Accountant I', 'Brandon R. LeBlanc', 'F', 'Yes', 'No', 'Black or African American', '1987-11-24', '2008-10-27', 0, 14, 0, 3, 1),
#  ('Buccheri, Joseph  ', 10184, 5, 65288, 20, 'MA', '1983-07-28', 'Single', '2014-09-29', None, None, 'Production       ', 'Google Search', 'Fully Meets', 3.19, 3, 0, 9, 'Production Technician II', 'Webster Butler', 'M ', 'No', 'No', 'White', '1983-07-28', '2014-09-29', 0, 8, 1, 3, 0),
#  ('Bugali, Josephine ', 10203, 5, 64375, 19, 'MA', '1969-10-30', 'Separated', '2013-11-11', None, 20.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 3.5, 5, 0, 17, 'Production Technician I', 'Kissy Sullivan', 'F', 'Yes', 'No', 'Black or African American', '1969-10-30', '2013-11-11', 0, 9, None, 3, 1),
#  ('Bunbury, Jessica', 10188, 6, 74326, 3, 'VA', '1964-06-01', 'Married', '2011-08-15', '2014-08-02', 17.0, 'Sales', 'Google Search', 'Fully Meets', 3.14, 5, 0, 19, 'Area Sales Manager', 'John Smith', 'F', 'No', 'No', 'Black or African American', '1964-06-01', '2011-08-15', 1, 2, 0, 3, 0),
#  ('Burke, Joelle', 10107, 5, 63763, 20, 'MA', '1980-03-02', 'Single', '2012-03-05', None, 11.0, 'Production       ', 'Employee Referral', 'Fully Meets', 4.51, 4, 0, 3, 'Production Technician II', 'Amy Dunn', 'F', 'No', 'No', 'Black or African American', '1980-03-02', '2012-03-05', 0, 11, 1, 3, 0),
#  ('Burkett, Benjamin ', 10181, 5, 62162, 20, 'MA', '1977-08-19', 'Married', '2011-04-04', None, 19.0, 'Production       ', 'Indeed', 'Fully Meets', 3.25, 5, 0, 15, 'Production Technician II', 'Ketsia Liebig', 'M ', 'No', 'No', 'White', '1977-08-19', '2011-04-04', 0, 12, 0, 3, 0),
#  ('Cady, Max ', 10150, 4, 77692, 25, 'MA', '1966-11-22', 'Single', '2011-08-15', None, 5.0, 'Software Engineering', 'Google Search', 'Fully Meets', 3.84, 3, 5, 4, 'Software Engineering Manager', 'Jennifer Zamora', 'M ', 'No', 'No', 'White', '1966-11-22', '2011-08-15', 0, 12, 1, 3, 0),
#  ('Candie, Calvin', 10001, 5, 72640, 18, 'MA', '1983-08-09', 'Single', '2016-01-28', None, 2.0, 'Production       ', 'Indeed', 'Exceeds', 5.0, 3, 0, 14, 'Production Manager', 'Janet King', 'M ', 'No', 'No', 'White', '1983-08-09', '2016-01-28', 0, 7, 1, 4, 0),
#  ('Carabbio, Judith', 10085, 4, 93396, 24, 'MA', '1987-04-05', 'Single', '2013-11-11', None, 10.0, 'Software Engineering', 'Indeed', 'Fully Meets', 4.96, 4, 6, 3, 'Software Engineer', 'Alex Sweetwater', 'F', 'No', 'No', 'White', '1987-04-05', '2013-11-11', 0, 9, 1, 3, 0),
#  ('Carey, Michael  ', 10115, 5, 52846, 19, 'MA', '1983-02-02', 'Single', '2014-03-31', None, 18.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.43, 3, 0, 14, 'Production Technician I', 'Kelley Spirea', 'M ', 'No', 'No', 'Black or African American', '1983-02-02', '2014-03-31', 0, 9, 1, 3, 0),
#  ('Carr, Claudia  N', 10082, 3, 100031, 27, 'MA', '1986-06-06', 'Single', '2016-06-30', None, 4.0, 'IT/IS', 'LinkedIn', 'Fully Meets', 5.0, 5, 6, 7, 'Sr. DBA', 'Simon Roup', 'F', 'No', 'No', 'Black or African American', '1986-06-06', '2016-06-30', 0, 7, 1, 3, 0),
#  ('Carter, Michelle ', 10040, 6, 71860, 3, 'VT', '1963-05-15', 'Single', '2014-08-18', None, 17.0, 'Sales', 'Indeed', 'Fully Meets', 5.0, 5, 0, 7, 'Area Sales Manager', 'John Smith', 'F', 'No', 'No', 'White', '1963-05-15', '2014-08-18', 0, 9, 1, 3, 0),
#  ('Chace, Beatrice ', 10067, 5, 61656, 19, 'MA', '1951-01-02', 'Single', '2014-09-29', None, 22.0, 'Production       ', 'Google Search', 'Fully Meets', 5.0, 4, 0, 11, 'Production Technician I', 'Michael Albert', 'F', 'No', 'No', 'White', '1951-01-02', '2014-09-29', 0, 8, 1, 3, 0),
#  ('Champaigne, Brian', 10108, 3, 110929, 5, 'MA', '1972-02-09', 'Married', '2016-09-06', None, 5.0, 'IT/IS', 'Indeed', 'Fully Meets', 4.5, 5, 7, 8, 'BI Director', 'Jennifer Zamora', 'M ', 'No', 'No', 'White', '1972-02-09', '2016-09-06', 0, 7, 0, 3, 0),
#  ('Chan, Lin', 10210, 5, 54237, 19, 'MA', '1979-02-12', 'Single', '2014-05-12', None, 16.0, 'Production       ', 'Indeed', 'Fully Meets', 3.3, 4, 0, 11, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1979-02-12', '2014-05-12', 0, 9, 1, 3, 0),
#  ('Chang, Donovan  E', 10154, 5, 60380, 19, 'MA', '1983-08-24', 'Single', '2013-07-08', None, None, 'Production       ', 'LinkedIn', 'Fully Meets', 3.8, 5, 0, 4, 'Production Technician I', 'Webster Butler', 'M ', 'No', 'No', 'White', '1983-08-24', '2013-07-08', 0, 10, 1, 3, 0),
#  ('Chigurh, Anton', 10200, 6, 66808, 3, 'TX', '1970-06-11', 'Single', '2012-05-14', None, 21.0, 'Sales', 'Employee Referral', 'Fully Meets', 3.0, 5, 0, 17, 'Area Sales Manager', 'Lynn Daneault', 'M ', 'No', 'No', 'Black or African American', '1970-06-11', '2012-05-14', 0, 11, 1, 3, 0),
#  ('Chivukula, Enola', 10240, 5, 64786, 19, 'MA', '1983-08-27', 'Single', '2011-06-27', '2015-11-15', 11.0, 'Production       ', 'Indeed', 'Fully Meets', 4.3, 4, 0, 3, 'Production Technician I', 'Amy Dunn', 'F', 'No', 'No', 'White', '1983-08-27', '2011-06-27', 1, 4, 1, 3, 0),
#  ('Cierpiszewski, Caroline  ', 10168, 5, 64816, 19, 'MA', '1988-05-31', 'Single', '2011-10-03', None, 19.0, 'Production       ', 'Indeed', 'Fully Meets', 3.58, 5, 0, 3, 'Production Technician I', 'Ketsia Liebig', 'F', 'No', 'No', 'Black or African American', '1988-05-31', '2011-10-03', 0, 11, 1, 3, 0),
#  ('Clayton, Rick', 10220, 3, 68678, 14, 'MA', '1985-09-05', 'Single', '2012-09-05', None, 6.0, 'IT/IS', 'Indeed', 'Fully Meets', 4.7, 3, 6, 2, 'IT Support', 'Eric Dougall', 'M ', 'No', 'No', 'White', '1985-09-05', '2012-09-05', 0, 11, 1, 3, 0),
#  ('Cloninger, Jennifer', 10275, 5, 64066, 20, 'MA', '1981-08-31', 'Married', '2011-05-16', '2013-01-07', 12.0, 'Production       ', 'Google Search', 'Fully Meets', 4.2, 5, 0, 9, 'Production Technician II', 'Brannon Miller', 'F', 'No', 'No', 'White', '1981-08-31', '2011-05-16', 1, 1, 0, 3, 0),
#  ('Close, Phil', 10269, 5, 59369, 20, 'MA', '1978-11-25', 'Married', '2010-08-30', '2011-09-26', 14.0, 'Production       ', 'Indeed', 'Fully Meets', 4.2, 4, 0, 6, 'Production Technician II', 'David Stanley', 'M ', 'No', 'No', 'White', '1978-11-25', '2010-08-30', 1, 1, 0, 3, 0),
#  ('Clukey, Elijian', 10029, 5, 50373, 19, 'MA', '1980-08-26', 'Married', '2016-07-06', None, 12.0, 'Production       ', 'Employee Referral', 'Exceeds', 4.1, 4, 0, 5, 'Production Technician I', 'Brannon Miller', 'M ', 'No', 'No', 'White', '1980-08-26', '2016-07-06', 0, 7, 0, 4, 0),
#  ('Cockel, James', 10261, 5, 63108, 19, 'MA', '1977-09-08', 'Single', '2013-07-08', None, 14.0, 'Production       ', 'Employee Referral', 'Fully Meets', 4.4, 5, 0, 3, 'Production Technician I', 'David Stanley', 'M ', 'No', 'No', 'White', '1977-09-08', '2013-07-08', 0, 10, 1, 3, 0),
#  ('Cole, Spencer', 10292, 5, 59144, 19, 'MA', '1979-08-12', 'Single', '2011-07-11', '2016-09-23', 20.0, 'Production       ', 'LinkedIn', 'Needs Improvement', 2.0, 3, 0, 16, 'Production Technician I', 'Kissy Sullivan', 'M ', 'No', 'No', 'Black or African American', '1979-08-12', '2011-07-11', 1, 5, 1, 2, 0),
#  ('Corleone, Michael', 10282, 5, 68051, 18, 'MA', '1975-12-17', 'Divorced', '2010-07-20', None, 2.0, 'Production       ', 'CareerBuilder', 'Needs Improvement', 4.13, 2, 0, 3, 'Production Manager', 'Janet King', 'M ', 'No', 'No', 'White', '1975-12-17', '2010-07-20', 0, 13, 1, 2, 0),
#  ('Corleone, Vito', 10019, 5, 170500, 10, 'MA', '1983-03-19', 'Single', '2009-01-05', None, 2.0, 'Production       ', 'Indeed', 'Exceeds', 3.7, 5, 0, 15, 'Director of Operations', 'Janet King', 'M ', 'No', 'No', 'Black or African American', '1983-03-19', '2009-01-05', 0, 14, 1, 4, 0),
#  ('Cornett, Lisa ', 10094, 5, 63381, 19, 'MA', '1977-03-31', 'Married', '2015-01-05', None, 18.0, 'Production       ', 'Indeed', 'Fully Meets', 4.73, 5, 0, 6, 'Production Technician I', 'Kelley Spirea', 'F', 'No', 'Yes', 'White', '1977-03-31', '2015-01-05', 0, 8, 0, 3, 0),
#  ('Costello, Frank', 10193, 3, 83552, 9, 'MA', '1986-08-26', 'Married', '2015-03-30', None, 4.0, 'IT/IS', 'Indeed', 'Fully Meets', 3.04, 3, 6, 2, 'Data Analyst', 'Simon Roup', 'M ', 'No', 'No', 'White', '1986-08-26', '2015-03-30', 0, 8, 0, 3, 0),
#  ('Crimmings,   Jean', 10132, 5, 56149, 19, 'MA', '1987-04-10', 'Single', '2016-07-06', None, 22.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.12, 5, 0, 15, 'Production Technician I', 'Michael Albert', 'F', 'No', 'No', 'White', '1987-04-10', '2016-07-06', 0, 7, 1, 3, 0),
#  ('Cross, Noah', 10083, 3, 92329, 28, 'CT', '1965-09-09', 'Single', '2014-11-10', None, 7.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 5.0, 3, 4, 5, 'Sr. Network Engineer', 'Peter Monroe', 'M ', 'No', 'No', 'White', '1965-09-09', '2014-11-10', 0, 8, 1, 3, 0),
#  ('Daneault, Lynn', 10099, 6, 65729, 21, 'VT', '1990-04-19', 'Single', '2014-05-05', None, 15.0, 'Sales', 'Indeed', 'Fully Meets', 4.62, 4, 0, 8, 'Sales Manager', 'Debra Houlihan', 'F', 'No', 'No', 'White', '1990-04-19', '2014-05-05', 0, 9, 1, 3, 0),
#  ('Daniele, Ann  ', 10212, 3, 85028, 28, 'CT', '1952-01-18', 'Married', '2014-11-10', None, 7.0, 'IT/IS', 'LinkedIn', 'Fully Meets', 3.1, 5, 8, 19, 'Sr. Network Engineer', 'Peter Monroe', 'F', 'No', 'No', 'White', '1952-01-18', '2014-11-10', 0, 8, 0, 3, 0),
#  ("Darson, Jene'ya ", 10056, 5, 57583, 19, 'MA', '1978-11-05', 'Married', '2012-07-02', None, 16.0, 'Production       ', 'Indeed', 'Fully Meets', 5.0, 3, 0, 1, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1978-11-05', '2012-07-02', 0, 11, 0, 3, 0),
#  ('Davis, Daniel', 10143, 5, 56294, 20, 'MA', '1979-09-14', 'Single', '2011-11-07', None, 20.0, 'Production       ', 'LinkedIn', 'Fully Meets', 3.96, 4, 0, 6, 'Production Technician II', 'Kissy Sullivan', 'M ', 'No', 'No', 'Two or more races', '1979-09-14', '2011-11-07', 0, 11, 1, 3, 0),
#  ('Dee, Randy', 10311, 6, 56991, 19, 'MA', '1988-04-15', 'Married', '2018-07-09', None, 12.0, 'Production       ', 'Indeed', 'Fully Meets', 4.3, 4, 3, 2, 'Production Technician I', 'Brannon Miller', 'M ', 'No', 'No', 'White', '1988-04-15', '2018-07-09', 0, 5, 0, 3, 0),
#  ('DeGweck,  James', 10070, 5, 55722, 19, 'MA', '1977-10-31', 'Married', '2011-05-16', '2016-06-08', 39.0, 'Production       ', 'Indeed', 'Fully Meets', 5.0, 4, 0, 14, 'Production Technician I', 'Webster Butler', 'M ', 'No', 'No', 'White', '1977-10-31', '2011-05-16', 1, 5, 0, 3, 0),
#  ('Del Bosque, Keyla', 10155, 4, 101199, 24, 'MA', '1979-07-05', 'Single', '2012-01-09', None, 10.0, 'Software Engineering', 'CareerBuilder', 'Fully Meets', 3.79, 5, 5, 8, 'Software Engineer', 'Alex Sweetwater', 'F', 'No', 'No', 'Black or African American', '1979-07-05', '2012-01-09', 0, 11, 1, 3, 0),
#  ('Delarge, Alex', 10306, 6, 61568, 3, 'AL', '1975-11-02', 'Single', '2014-09-29', None, 17.0, 'Sales', 'Indeed', 'PIP', 1.93, 3, 0, 5, 'Area Sales Manager', 'John Smith', 'M ', 'No', 'No', 'Two or more races', '1975-11-02', '2014-09-29', 0, 8, 1, 1, 0),
#  ('Demita, Carla', 10100, 5, 58275, 20, 'MA', '1951-02-25', 'Separated', '2011-04-04', '2015-11-04', 18.0, 'Production       ', 'Google Search', 'Fully Meets', 4.62, 5, 0, 1, 'Production Technician II', 'Kelley Spirea', 'F', 'No', 'No', 'Black or African American', '1951-02-25', '2011-04-04', 1, 4, None, 3, 0),
#  ('Desimone, Carl ', 10310, 5, 53189, 19, 'MA', '1967-04-19', 'Married', '2014-07-07', None, 11.0, 'Production       ', 'Indeed', 'PIP', 1.12, 2, 0, 9, 'Production Technician I', 'Amy Dunn', 'M ', 'No', 'No', 'White', '1967-04-19', '2014-07-07', 0, 9, 0, 1, 0),
#  ('DeVito, Tommy', 10197, 3, 96820, 4, 'MA', '1983-09-04', 'Single', '2017-02-15', None, 13.0, 'IT/IS', 'Indeed', 'Fully Meets', 3.01, 5, 7, 15, 'BI Developer', 'Brian Champaigne', 'M ', 'No', 'No', 'White', '1983-09-04', '2017-02-15', 0, 6, 1, 3, 0),
#  ('Dickinson, Geoff ', 10276, 5, 51259, 19, 'MA', '1982-11-15', 'Single', '2014-05-12', None, 19.0, 'Production       ', 'Indeed', 'Fully Meets', 4.3, 4, 0, 1, 'Production Technician I', 'Ketsia Liebig', 'M ', 'No', 'No', 'White', '1982-11-15', '2014-05-12', 0, 9, 1, 3, 0),
#  ('Dietrich, Jenna  ', 10304, 6, 59231, 3, 'WA', '1987-05-14', 'Single', '2012-02-20', None, 17.0, 'Sales', 'Website', 'PIP', 2.3, 1, 0, 17, 'Area Sales Manager', 'John Smith', 'F', 'No', 'Yes', 'White', '1987-05-14', '2012-02-20', 0, 11, 1, 1, 0),
#  ('DiNocco, Lily ', 10284, 5, 61584, 19, 'MA', '1978-12-02', 'Married', '2013-01-07', None, 12.0, 'Production       ', 'Indeed', 'Needs Improvement', 3.88, 4, 0, 6, 'Production Technician I', 'Brannon Miller', 'F', 'No', 'No', 'Black or African American', '1978-12-02', '2013-01-07', 0, 10, 0, 2, 0),
#  ('Dobrin, Denisa  S', 10207, 5, 46335, 19, 'MA', '1986-10-07', 'Single', '2012-04-02', None, 14.0, 'Production       ', 'CareerBuilder', 'Fully Meets', 3.4, 5, 0, 15, 'Production Technician I', 'David Stanley', 'F', 'No', 'Yes', 'White', '1986-10-07', '2012-04-02', 0, 11, 1, 3, 0),
#  ('Dolan, Linda', 10133, 3, 70621, 14, 'MA', '1988-07-18', 'Married', '2015-01-05', None, 7.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 4.11, 4, 6, 16, 'IT Support', 'Peter Monroe', 'F', 'No', 'No', 'White', '1988-07-18', '2015-01-05', 0, 8, 0, 3, 0),
#  ('Dougall, Eric', 10028, 3, 138888, 13, 'MA', '1970-07-09', 'Single', '2014-01-05', None, 5.0, 'IT/IS', 'Indeed', 'Exceeds', 4.3, 5, 5, 4, 'IT Manager', 'Jennifer Zamora', 'M ', 'No', 'No', 'Black or African American', '1970-07-09', '2014-01-05', 0, 9, 1, 4, 0),
#  ('Driver, Elle', 10006, 6, 74241, 3, 'CA', '1988-11-08', 'Single', '2011-01-10', None, 21.0, 'Sales', 'Indeed', 'Exceeds', 4.77, 5, 0, 14, 'Area Sales Manager', 'Lynn Daneault', 'F', 'No', 'No', 'White', '1988-11-08', '2011-01-10', 0, 12, 1, 4, 0),
#  ('Dunn, Amy  ', 10105, 5, 75188, 18, 'MA', '1973-11-28', 'Single', '2014-09-18', None, 2.0, 'Production       ', 'Google Search', 'Fully Meets', 4.52, 4, 0, 4, 'Production Manager', 'Janet King', 'F', 'No', 'No', 'White', '1973-11-28', '2014-09-18', 0, 9, 1, 3, 0),
#  ('Dunne, Amy', 10211, 5, 62514, 19, 'MA', '1973-09-23', 'Married', '2010-04-26', None, 19.0, 'Production       ', 'Google Search', 'Fully Meets', 2.9, 3, 0, 6, 'Production Technician I', 'Ketsia Liebig', 'F', 'No', 'No', 'White', '1973-09-23', '2010-04-26', 0, 13, 0, 3, 0),
#  ('Eaton, Marianne', 10064, 5, 60070, 19, 'MA', '1991-09-05', 'Married', '2011-04-04', '2017-06-06', 20.0, 'Production       ', 'Google Search', 'Fully Meets', 5.0, 3, 0, 7, 'Production Technician I', 'Kissy Sullivan', 'F', 'No', 'No', 'White', '1991-09-05', '2011-04-04', 1, 6, 0, 3, 0),
#  ('Engdahl, Jean', 10247, 5, 48888, 19, 'MA', '1974-05-31', 'Single', '2014-11-10', None, 18.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.7, 5, 0, 8, 'Production Technician I', 'Kelley Spirea', 'M ', 'No', 'No', 'White', '1974-05-31', '2014-11-10', 0, 8, 1, 3, 0),
#  ('England, Rex', 10235, 5, 54285, 19, 'MA', '1978-08-25', 'Married', '2014-03-31', None, 18.0, 'Production       ', 'Employee Referral', 'Fully Meets', 4.2, 3, 0, 3, 'Production Technician I', 'Kelley Spirea', 'M ', 'No', 'No', 'White', '1978-08-25', '2014-03-31', 0, 9, 0, 3, 0),
#  ('Erilus, Angela', 10299, 5, 56847, 20, 'MA', '1989-08-25', 'Separated', '2014-07-07', None, 22.0, 'Production       ', 'Indeed', 'PIP', 3.0, 1, 0, 5, 'Production Technician II', 'Michael Albert', 'F', 'No', 'No', 'White', '1989-08-25', '2014-07-07', 0, 9, None, 1, 0),
#  ('Estremera, Miguel', 10280, 5, 60340, 19, 'MA', '1983-09-02', 'Single', '2012-04-02', '2018-09-27', 22.0, 'Production       ', 'Google Search', 'Needs Improvement', 5.0, 4, 0, 16, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1983-09-02', '2012-04-02', 1, 6, 1, 2, 0),
#  ('Evensen, April', 10296, 5, 59124, 19, 'MA', '1989-05-06', 'Single', '2014-02-17', '2018-02-25', 16.0, 'Production       ', 'Google Search', 'Needs Improvement', 2.3, 3, 0, 19, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1989-05-06', '2014-02-17', 1, 4, 1, 2, 0),
#  ('Exantus, Susan', 10290, 4, 99280, 24, 'MA', '1987-05-15', 'Married', '2011-05-02', '2013-06-05', 10.0, 'Software Engineering', 'Indeed', 'Needs Improvement', 2.1, 5, 4, 19, 'Software Engineer', 'Alex Sweetwater', 'F', 'No', 'No', 'Black or African American', '1987-05-15', '2011-05-02', 1, 2, 0, 2, 0),
#  ('Faller, Megan ', 10263, 5, 71776, 20, 'MA', '1978-09-22', 'Married', '2014-07-07', None, 16.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.4, 5, 0, 17, 'Production Technician II', 'Elijiah Gray', 'F', 'No', 'No', 'Black or African American', '1978-09-22', '2014-07-07', 0, 9, 0, 3, 0),
#  ('Fancett, Nicole', 10136, 5, 65902, 20, 'MA', '1987-09-27', 'Single', '2014-02-17', None, None, 'Production       ', 'LinkedIn', 'Fully Meets', 4.0, 4, 0, 7, 'Production Technician II', 'Webster Butler', 'F', 'No', 'No', 'Black or African American', '1987-09-27', '2014-02-17', 0, 9, 1, 3, 0),
#  ('Ferguson, Susan', 10189, 5, 57748, 19, 'MA', '1955-04-14', 'Married', '2011-11-07', '2016-05-17', 39.0, 'Production       ', 'Google Search', 'Fully Meets', 3.13, 3, 0, 16, 'Production Technician I', 'Webster Butler', 'F', 'No', 'No', 'White', '1955-04-14', '2011-11-07', 1, 4, 0, 3, 0),
#  ('Fernandes, Nilson  ', 10308, 5, 64057, 19, 'MA', '1989-10-18', 'Married', '2015-05-11', None, 11.0, 'Production       ', 'Indeed', 'PIP', 1.56, 5, 0, 15, 'Production Technician I', 'Amy Dunn', 'M ', 'No', 'No', 'White', '1989-10-18', '2015-05-11', 0, 8, 0, 1, 0),
#  ('Fett, Boba', 10309, 3, 53366, 15, 'MA', '1987-06-18', 'Single', '2015-03-30', None, 7.0, 'IT/IS', 'LinkedIn', 'PIP', 1.2, 3, 6, 2, 'Network Engineer', 'Peter Monroe', 'M ', 'No', 'No', 'White', '1987-06-18', '2015-03-30', 0, 8, 1, 1, 0),
#  ('Fidelia,  Libby', 10049, 5, 58530, 19, 'MA', '1981-03-16', 'Married', '2012-01-09', None, 12.0, 'Production       ', 'Google Search', 'Fully Meets', 5.0, 5, 0, 19, 'Production Technician I', 'Brannon Miller', 'F', 'No', 'No', 'White', '1981-03-16', '2012-01-09', 0, 11, 0, 3, 0),
#  ('Fitzpatrick, Michael  J', 10093, 5, 72609, 20, 'MA', '1981-10-01', 'Single', '2011-05-16', '2013-06-24', 11.0, 'Production       ', 'Google Search', 'Fully Meets', 4.76, 5, 0, 20, 'Production Technician II', 'Amy Dunn', 'M ', 'No', 'Yes', 'White', '1981-10-01', '2011-05-16', 1, 2, 1, 3, 0),
#  ('Foreman, Tanya', 10163, 5, 55965, 20, 'MA', '1983-11-08', 'Married', '2011-04-04', '2013-01-09', 19.0, 'Production       ', 'Google Search', 'Fully Meets', 3.66, 3, 0, 6, 'Production Technician II', 'Ketsia Liebig', 'F', 'No', 'No', 'White', '1983-11-08', '2011-04-04', 1, 1, 0, 3, 0),
#  ('Forrest, Alex', 10305, 6, 70187, 3, 'MA', '1975-07-07', 'Married', '2014-09-29', '2018-08-19', 21.0, 'Sales', 'Employee Referral', 'PIP', 2.0, 5, 0, 7, 'Area Sales Manager', 'Lynn Daneault', 'M ', 'No', 'No', 'White', '1975-07-07', '2014-09-29', 1, 3, 0, 1, 0),
#  ('Foss, Jason', 10015, 3, 178000, 12, 'MA', '1980-07-05', 'Single', '2011-04-15', None, 5.0, 'IT/IS', 'Indeed', 'Exceeds', 5.0, 5, 5, 15, 'IT Director', 'Jennifer Zamora', 'M ', 'No', 'No', 'Black or African American', '1980-07-05', '2011-04-15', 0, 12, 1, 4, 0),
#  ('Foster-Baker, Amy', 10080, 1, 99351, 26, 'MA', '1979-04-16', 'Married', '2009-01-05', None, 9.0, 'Admin Offices', 'Other', 'Fully Meets', 5.0, 3, 2, 3, 'Sr. Accountant', 'Board of Directors', 'F', 'No', 'no', 'White', '1979-04-16', '2009-01-05', 0, 14, 0, 3, 0),
#  ('Fraval, Maruk ', 10258, 6, 67251, 3, 'CT', '1963-08-28', 'Single', '2011-09-06', None, 21.0, 'Sales', 'CareerBuilder', 'Fully Meets', 4.3, 3, 0, 7, 'Area Sales Manager', 'Lynn Daneault', 'M ', 'No', 'No', 'Black or African American', '1963-08-28', '2011-09-06', 0, 12, 1, 3, 0),
#  ('Galia, Lisa', 10273, 3, 65707, 14, 'CT', '1968-07-06', 'Single', '2010-05-01', None, 6.0, 'IT/IS', 'LinkedIn', 'Fully Meets', 4.7, 4, 5, 1, 'IT Support', 'Eric Dougall', 'F', 'No', 'No', 'White', '1968-07-06', '2010-05-01', 0, 13, 1, 3, 0),
#  ('Garcia, Raul', 10111, 5, 52249, 19, 'MA', '1985-09-15', 'Single', '2015-03-30', None, 14.0, 'Production       ', 'Employee Referral', 'Fully Meets', 4.5, 3, 0, 5, 'Production Technician I', 'David Stanley', 'M ', 'No', 'Yes', 'White', '1985-09-15', '2015-03-30', 0, 8, 1, 3, 0),
#  ('Gaul, Barbara', 10257, 5, 53171, 19, 'MA', '1983-12-02', 'Single', '2011-05-16', None, 18.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.2, 4, 0, 12, 'Production Technician I', 'Kelley Spirea', 'F', 'No', 'Yes', 'Black or African American', '1983-12-02', '2011-05-16', 0, 12, 1, 3, 0),
#  ('Gentry, Mildred', 10159, 5, 51337, 19, 'MA', '1990-10-01', 'Married', '2015-03-30', None, 22.0, 'Production       ', 'LinkedIn', 'Fully Meets', 3.73, 3, 0, 19, 'Production Technician I', 'Michael Albert', 'F', 'No', 'No', 'Black or African American', '1990-10-01', '2015-03-30', 0, 8, 0, 3, 0),
#  ('Gerke, Melisa', 10122, 5, 51505, 19, 'MA', '1970-05-15', 'Divorced', '2011-11-07', '2016-11-15', 16.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.24, 4, 0, 2, 'Production Technician I', 'Elijiah Gray', 'F', 'Yes', 'No', 'Black or African American', '1970-05-15', '2011-11-07', 1, 5, 1, 3, 1),
#  ('Gill, Whitney  ', 10142, 6, 59370, 3, 'OH', '1971-07-10', 'Widowed', '2014-07-07', '2015-09-05', 17.0, 'Sales', 'CareerBuilder', 'Fully Meets', 3.97, 4, 0, 7, 'Area Sales Manager', 'John Smith', 'F', 'No', 'No', 'Black or African American', '1971-07-10', '2014-07-07', 1, 1, 1, 3, 0),
#  ('Gilles, Alex', 10283, 5, 54933, 19, 'MA', '1974-08-09', 'Married', '2012-04-02', '2015-06-25', 39.0, 'Production       ', 'Diversity Job Fair', 'Needs Improvement', 3.97, 4, 0, 15, 'Production Technician I', 'Webster Butler', 'M ', 'Yes', 'No', 'Black or African American', '1974-08-09', '2012-04-02', 1, 3, 0, 2, 1),
#  ('Girifalco, Evelyn', 10018, 5, 57815, 19, 'MA', '1980-05-08', 'Single', '2014-09-29', None, 11.0, 'Production       ', 'Indeed', 'Exceeds', 3.9, 4, 0, 3, 'Production Technician I', 'Amy Dunn', 'F', 'No', 'Yes', 'Two or more races', '1980-05-08', '2014-09-29', 0, 8, 1, 4, 0),
#  ('Givens, Myriam', 10255, 6, 61555, 3, 'IN', '1989-09-22', 'Single', '2015-02-16', None, 21.0, 'Sales', 'Indeed', 'Fully Meets', 4.5, 5, 0, 20, 'Area Sales Manager', 'Lynn Daneault', 'F', 'No', 'No', 'White', '1989-09-22', '2015-02-16', 0, 8, 1, 3, 0),
#  ('Goble, Taisha', 10246, 3, 114800, 8, 'MA', '1971-10-23', 'Single', '2015-02-16', '2015-03-15', 4.0, 'IT/IS', 'Indeed', 'Fully Meets', 4.6, 4, 4, 10, 'Database Administrator', 'Simon Roup', 'F', 'No', 'No', 'White', '1971-10-23', '2015-02-16', 1, 0, 1, 3, 0),
#  ('Goeth, Amon', 10228, 3, 74679, 14, 'MA', '1989-11-24', 'Married', '2015-03-30', None, 7.0, 'IT/IS', 'LinkedIn', 'Fully Meets', 4.3, 5, 7, 20, 'IT Support', 'Peter Monroe', 'M ', 'No', 'Yes', 'White', '1989-11-24', '2015-03-30', 0, 8, 0, 3, 0),
#  ('Gold, Shenice  ', 10243, 5, 53018, 19, 'MA', '1992-06-18', 'Single', '2013-11-11', None, 19.0, 'Production       ', 'Indeed', 'Fully Meets', 4.3, 5, 0, 7, 'Production Technician I', 'Ketsia Liebig', 'F', 'No', 'Yes', 'White', '1992-06-18', '2013-11-11', 0, 9, 1, 3, 0),
#  ('Gonzalez, Cayo', 10031, 5, 59892, 19, 'MA', '1969-09-29', 'Divorced', '2011-07-11', None, 12.0, 'Production       ', 'Diversity Job Fair', 'Exceeds', 4.5, 4, 0, 1, 'Production Technician I', 'Brannon Miller', 'M ', 'Yes', 'No', 'Black or African American', '1969-09-29', '2011-07-11', 0, 12, 1, 4, 1),
#  ('Gonzalez, Juan', 10300, 5, 68898, 20, 'MA', '1964-10-12', 'Married', '2010-04-26', '2011-05-30', 12.0, 'Production       ', 'Diversity Job Fair', 'PIP', 3.0, 3, 0, 10, 'Production Technician II', 'Brannon Miller', 'M ', 'Yes', 'No', 'Black or African American', '1964-10-12', '2010-04-26', 1, 1, 0, 1, 1),
#  ('Gonzalez, Maria', 10101, 3, 61242, 14, 'MA', '1981-04-16', 'Separated', '2015-01-05', None, 7.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 4.61, 4, 5, 11, 'IT Support', 'Peter Monroe', 'F', 'No', 'Yes', 'White', '1981-04-16', '2015-01-05', 0, 8, None, 3, 0),
#  ('Good, Susan', 10237, 5, 66825, 20, 'MA', '1986-05-25', 'Married', '2014-05-12', None, 14.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.6, 3, 0, 20, 'Production Technician II', 'David Stanley', 'F', 'No', 'No', 'White', '1986-05-25', '2014-05-12', 0, 9, 0, 3, 0),
#  ('Gordon, David', 10051, 5, 48285, 19, 'MA', '1979-05-21', 'Married', '2012-07-02', None, 14.0, 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 3, 0, 2, 'Production Technician I', 'David Stanley', 'M ', 'No', 'No', 'White', '1979-05-21', '2012-07-02', 0, 11, 0, 3, 0),
#  ('Gosciminski, Phylicia  ', 10218, 5, 66149, 20, 'MA', '1983-12-08', 'Separated', '2013-09-30', None, 20.0, 'Production       ', 'Google Search', 'Fully Meets', 4.4, 5, 0, 1, 'Production Technician II', 'Kissy Sullivan', 'F', 'No', 'No', 'American Indian or Alaska Native', '1983-12-08', '2013-09-30', 0, 9, None, 3, 0),
#  ('Goyal, Roxana', 10256, 5, 49256, 19, 'MA', '1974-10-09', 'Married', '2013-08-19', None, 20.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.1, 5, 0, 3, 'Production Technician I', 'Kissy Sullivan', 'F', 'No', 'No', 'Asian', '1974-10-09', '2013-08-19', 0, 10, 0, 3, 0),
#  ('Gray, Elijiah  ', 10098, 5, 62957, 18, 'MA', '1981-07-11', 'Divorced', '2015-06-02', None, 2.0, 'Production       ', 'Employee Referral', 'Fully Meets', 4.63, 3, 0, 2, 'Production Manager', 'Janet King', 'M ', 'No', 'No', 'White', '1981-07-11', '2015-06-02', 0, 8, 1, 3, 0),
#  ('Gross, Paula', 10059, 5, 63813, 19, 'MA', '1983-05-21', 'Divorced', '2011-02-21', '2014-01-11', 18.0, 'Production       ', 'CareerBuilder', 'Fully Meets', 5.0, 5, 0, 17, 'Production Technician I', 'Kelley Spirea', 'F', 'No', 'No', 'White', '1983-05-21', '2011-02-21', 1, 2, 1, 3, 0),
#  ('Gruber, Hans', 10234, 3, 99020, 4, 'MA', '1989-06-30', 'Married', '2017-04-20', None, 13.0, 'IT/IS', 'Indeed', 'Fully Meets', 4.2, 5, 5, 8, 'BI Developer', 'Brian Champaigne', 'M ', 'No', 'No', 'Black or African American', '1989-06-30', '2017-04-20', 0, 6, 0, 3, 0),
#  ('Guilianno, Mike', 10109, 6, 71707, 3, 'TN', '1969-02-09', 'Single', '2012-03-07', '2014-10-31', 17.0, 'Sales', 'LinkedIn', 'Fully Meets', 4.5, 5, 0, 20, 'Area Sales Manager', 'John Smith', 'M ', 'No', 'No', 'Two or more races', '1969-02-09', '2012-03-07', 1, 2, 1, 3, 0),
#  ('Handschiegl, Joanne', 10125, 5, 54828, 19, 'MA', '1977-03-23', 'Married', '2011-11-28', None, 22.0, 'Production       ', 'Google Search', 'Fully Meets', 4.2, 4, 0, 13, 'Production Technician I', 'Michael Albert', 'F', 'No', 'No', 'White', '1977-03-23', '2011-11-28', 0, 11, 0, 3, 0),
#  ('Hankard, Earnest', 10074, 5, 64246, 20, 'MA', '1988-08-10', 'Single', '2013-11-11', None, 18.0, 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 3, 0, 20, 'Production Technician II', 'Kelley Spirea', 'M ', 'No', 'Yes', 'White', '1988-08-10', '2013-11-11', 0, 9, 1, 3, 0),
#  ('Harrington, Christie ', 10097, 5, 52177, 19, 'MA', '1952-08-18', 'Single', '2012-01-09', '2015-12-15', 39.0, 'Production       ', 'CareerBuilder', 'Fully Meets', 4.64, 4, 0, 8, 'Production Technician I', 'Webster Butler', 'F', 'No', 'No', 'White', '1952-08-18', '2012-01-09', 1, 3, 1, 3, 0),
#  ('Harrison, Kara', 10007, 5, 62065, 19, 'MA', '1974-05-02', 'Married', '2014-05-12', None, 11.0, 'Production       ', 'CareerBuilder', 'Exceeds', 4.76, 4, 0, 5, 'Production Technician I', 'Amy Dunn', 'F', 'No', 'No', 'White', '1974-05-02', '2014-05-12', 0, 9, 0, 4, 0),
#  ('Heitzman, Anthony', 10129, 5, 46998, 19, 'MA', '1984-01-04', 'Single', '2012-08-13', None, 19.0, 'Production       ', 'Google Search', 'Fully Meets', 4.17, 4, 0, 1, 'Production Technician I', 'Ketsia Liebig', 'M ', 'No', 'No', 'White', '1984-01-04', '2012-08-13', 0, 11, 1, 3, 0),
#  ('Hendrickson, Trina', 10075, 5, 68099, 20, 'MA', '1972-08-27', 'Single', '2011-01-10', '2013-06-18', 18.0, 'Production       ', 'CareerBuilder', 'Fully Meets', 5.0, 3, 0, 15, 'Production Technician II', 'Kelley Spirea', 'F', 'No', 'No', 'White', '1972-08-27', '2011-01-10', 1, 2, 1, 3, 0),
#  ('Hitchcock, Alfred', 10167, 6, 70545, 3, 'NH', '1988-09-14', 'Married', '2014-08-18', None, 17.0, 'Sales', 'Indeed', 'Fully Meets', 3.6, 5, 0, 9, 'Area Sales Manager', 'John Smith', 'M ', 'No', 'No', 'American Indian or Alaska Native', '1988-09-14', '2014-08-18', 0, 9, 0, 3, 0),
#  ('Homberger, Adrienne  J', 10195, 5, 63478, 20, 'MA', '1984-02-16', 'Married', '2011-08-15', '2012-04-07', 30.0, 'Production       ', 'Indeed', 'Fully Meets', 3.03, 5, 0, 16, 'Production Technician II', 'Michael Albert', 'F', 'No', 'No', 'White', '1984-02-16', '2011-08-15', 1, 0, 0, 3, 0),
#  ('Horton, Jayne', 10112, 3, 97999, 8, 'MA', '1984-02-21', 'Single', '2015-03-30', None, 4.0, 'IT/IS', 'Indeed', 'Fully Meets', 4.48, 5, 6, 4, 'Database Administrator', 'Simon Roup', 'F', 'No', 'No', 'White', '1984-02-21', '2015-03-30', 0, 8, 1, 3, 0),
#  ('Houlihan, Debra', 10272, 6, 180000, 11, 'RI', '1966-03-17', 'Married', '2014-05-05', None, 2.0, 'Sales', 'LinkedIn', 'Fully Meets', 4.5, 4, 0, 19, 'Director of Sales', 'Janet King', 'F', 'No', 'No', 'White', '1966-03-17', '2014-05-05', 0, 9, 0, 3, 0),
#  ('Howard, Estelle', 10182, 1, 49920, 2, 'MA', '1985-09-16', 'Married', '2015-02-16', '2015-04-15', 1.0, 'Admin Offices', 'Indeed', 'Fully Meets', 3.24, 3, 4, 6, 'Administrative Assistant', 'Brandon R. LeBlanc', 'F', 'No', 'No', 'Black or African American', '1985-09-16', '2015-02-16', 1, 0, 0, 3, 0),
#  ('Hudson, Jane', 10248, 5, 55425, 19, 'MA', '1986-06-10', 'Single', '2012-02-20', None, 19.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.8, 4, 0, 4, 'Production Technician I', 'Ketsia Liebig', 'F', 'No', 'No', 'White', '1986-06-10', '2012-02-20', 0, 11, 1, 3, 0),
#  ('Hunts, Julissa', 10201, 5, 69340, 20, 'MA', '1984-03-11', 'Single', '2016-06-06', None, 16.0, 'Production       ', 'LinkedIn', 'Fully Meets', 3.0, 5, 0, 4, 'Production Technician II', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1984-03-11', '2016-06-06', 0, 7, 1, 3, 0),
#  ('Hutter, Rosalie', 10214, 5, 64995, 20, 'MA', '1992-05-07', 'Separated', '2015-06-05', None, None, 'Production       ', 'Indeed', 'Fully Meets', 4.5, 3, 0, 6, 'Production Technician II', 'Webster Butler', 'F', 'No', 'No', 'White', '1992-05-07', '2015-06-05', 0, 8, None, 3, 0),
#  ('Huynh, Ming', 10160, 5, 68182, 20, 'MA', '1976-09-22', 'Divorced', '2011-02-21', '2013-04-01', 11.0, 'Production       ', 'Google Search', 'Fully Meets', 3.72, 3, 0, 18, 'Production Technician II', 'Amy Dunn', 'F', 'No', 'No', 'White', '1976-09-22', '2011-02-21', 1, 2, 1, 3, 0),
#  ('Immediato, Walter', 10289, 5, 83082, 18, 'MA', '1976-11-15', 'Married', '2011-02-21', '2012-09-24', 2.0, 'Production       ', 'Indeed', 'Needs Improvement', 2.34, 2, 0, 4, 'Production Manager', 'Janet King', 'M ', 'No', 'No', 'Asian', '1976-11-15', '2011-02-21', 1, 1, 0, 2, 0),
#  ('Ivey, Rose ', 10139, 5, 51908, 19, 'MA', '1991-01-28', 'Single', '2013-08-19', None, 12.0, 'Production       ', 'Indeed', 'Fully Meets', 3.99, 3, 0, 14, 'Production Technician I', 'Brannon Miller', 'F', 'No', 'No', 'White', '1991-01-28', '2013-08-19', 0, 10, 1, 3, 0),
#  ('Jackson, Maryellen', 10227, 5, 61242, 19, 'MA', '1972-09-11', 'Single', '2012-11-05', None, 14.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.1, 3, 0, 7, 'Production Technician I', 'David Stanley', 'F', 'No', 'No', 'Black or African American', '1972-09-11', '2012-11-05', 0, 10, 1, 3, 0),
#  ('Jacobi, Hannah  ', 10236, 5, 45069, 19, 'MA', '1966-03-22', 'Divorced', '2013-09-30', None, 20.0, 'Production       ', 'Employee Referral', 'Fully Meets', 4.3, 5, 0, 7, 'Production Technician I', 'Kissy Sullivan', 'F', 'No', 'No', 'White', '1966-03-22', '2013-09-30', 0, 9, 1, 3, 0),
#  ('Jeannite, Tayana', 10009, 5, 60724, 20, 'MA', '1986-11-06', 'Divorced', '2011-07-05', None, 19.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 4, 0, 11, 'Production Technician II', 'Ketsia Liebig', 'F', 'No', 'No', 'American Indian or Alaska Native', '1986-11-06', '2011-07-05', 0, 12, 1, 4, 0),
#  ('Jhaveri, Sneha  ', 10060, 5, 60436, 19, 'MA', '1964-04-13', 'Separated', '2014-01-06', None, 18.0, 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 5, 0, 9, 'Production Technician I', 'Kelley Spirea', 'F', 'No', 'No', 'White', '1964-04-13', '2014-01-06', 0, 9, None, 3, 0),
#  ('Johnson, George', 10034, 5, 46837, 19, 'MA', '1959-08-19', 'Married', '2011-11-07', '2018-04-29', 22.0, 'Production       ', 'CareerBuilder', 'Exceeds', 4.7, 4, 0, 9, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1959-08-19', '2011-11-07', 1, 6, 0, 4, 0),
#  ('Johnson, Noelle ', 10156, 3, 105700, 8, 'MA', '1986-11-07', 'Married', '2015-01-05', None, 4.0, 'IT/IS', 'Indeed', 'Fully Meets', 3.75, 3, 5, 2, 'Database Administrator', 'Simon Roup', 'F', 'No', 'No', 'Asian', '1986-11-07', '2015-01-05', 0, 8, 0, 3, 0),
#  ('Johnston, Yen', 10036, 5, 63322, 20, 'MA', '1969-09-08', 'Single', '2014-07-07', None, 12.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.3, 3, 0, 1, 'Production Technician II', 'Brannon Miller', 'F', 'No', 'No', 'White', '1969-09-08', '2014-07-07', 0, 9, 1, 4, 0),
#  ('Jung, Judy  ', 10138, 5, 61154, 19, 'MA', '1986-04-17', 'Married', '2011-01-10', '2016-04-01', 16.0, 'Production       ', 'CareerBuilder', 'Fully Meets', 4.0, 4, 0, 4, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'Black or African American', '1986-04-17', '2011-01-10', 1, 5, 0, 3, 0),
#  ('Kampew, Donysha', 10244, 6, 68999, 21, 'PA', '1989-11-11', 'Single', '2011-11-07', '2014-04-24', 15.0, 'Sales', 'Google Search', 'Fully Meets', 4.5, 5, 0, 2, 'Sales Manager', 'Debra Houlihan', 'F', 'No', 'No', 'White', '1989-11-11', '2011-11-07', 1, 2, 1, 3, 0),
#  ('Keatts, Kramer ', 10192, 5, 50482, 19, 'MA', '1976-01-19', 'Single', '2013-09-30', None, 22.0, 'Production       ', 'Indeed', 'Fully Meets', 3.07, 4, 0, 10, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'No', 'White', '1976-01-19', '2013-09-30', 0, 9, 1, 3, 0),
#  ('Khemmich, Bartholemew', 10231, 6, 65310, 3, 'CO', '1979-11-27', 'Single', '2013-08-19', None, 21.0, 'Sales', 'Indeed', 'Fully Meets', 4.3, 5, 0, 13, 'Area Sales Manager', 'Lynn Daneault', 'M ', 'No', 'No', 'White', '1979-11-27', '2013-08-19', 0, 10, 1, 3, 0),
#  ('King, Janet', 10089, 2, 250000, 16, 'MA', '1954-09-21', 'Married', '2012-07-02', None, 9.0, 'Executive Office', 'Indeed', 'Fully Meets', 4.83, 3, 0, 10, 'President & CEO', 'Board of Directors', 'F', 'No', 'Yes', 'White', '1954-09-21', '2012-07-02', 0, 11, 0, 3, 0),
#  ('Kinsella, Kathleen  ', 10166, 5, 54005, 19, 'MA', '1973-12-08', 'Married', '2011-09-26', '2015-06-04', 39.0, 'Production       ', 'Google Search', 'Fully Meets', 3.6, 5, 0, 16, 'Production Technician I', 'Webster Butler', 'F', 'No', 'No', 'White', '1973-12-08', '2011-09-26', 1, 3, 0, 3, 0),
#  ('Kirill, Alexandra  ', 10170, 5, 45433, 19, 'MA', '1970-10-08', 'Married', '2011-09-26', '2014-01-09', 11.0, 'Production       ', 'Google Search', 'Fully Meets', 3.49, 4, 0, 6, 'Production Technician I', 'Amy Dunn', 'F', 'No', 'No', 'White', '1970-10-08', '2011-09-26', 1, 2, 0, 3, 0),
#  ('Knapp, Bradley  J', 10208, 5, 46654, 19, 'MA', '1977-11-10', 'Single', '2014-02-17', None, 19.0, 'Production       ', 'LinkedIn', 'Fully Meets', 3.1, 3, 0, 3, 'Production Technician I', 'Ketsia Liebig', 'M ', 'No', 'No', 'Black or African American', '1977-11-10', '2014-02-17', 0, 9, 1, 3, 0),
#  ('Kretschmer, John', 10176, 5, 63973, 19, 'MA', '1980-02-02', 'Married', '2011-01-10', None, 12.0, 'Production       ', 'Indeed', 'Fully Meets', 3.38, 3, 0, 17, 'Production Technician I', 'Brannon Miller', 'M ', 'No', 'No', 'Asian', '1980-02-02', '2011-01-10', 0, 12, 0, 3, 0),
#  ('Kreuger, Freddy', 10165, 6, 71339, 3, 'NY', '1969-02-24', 'Single', '2011-03-07', None, 17.0, 'Sales', 'Diversity Job Fair', 'Fully Meets', 3.65, 5, 0, 20, 'Area Sales Manager', 'John Smith', 'M ', 'Yes', 'Yes', 'Black or African American', '1969-02-24', '2011-03-07', 0, 12, 1, 3, 1),
#  ('Lajiri,  Jyoti', 10113, 3, 93206, 28, 'MA', '1986-04-23', 'Married', '2014-11-10', None, 7.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 4.46, 5, 6, 7, 'Sr. Network Engineer', 'Peter Monroe', 'M ', 'No', 'No', 'White', '1986-04-23', '2014-11-10', 0, 8, 0, 3, 0),
#  ('Landa, Hans', 10092, 5, 82758, 18, 'MA', '1972-07-01', 'Married', '2011-01-10', '2015-12-12', 2.0, 'Production       ', 'Employee Referral', 'Fully Meets', 4.78, 4, 0, 9, 'Production Manager', 'Janet King', 'M ', 'No', 'No', 'White', '1972-07-01', '2011-01-10', 1, 4, 0, 3, 0),
#  ('Langford, Lindsey', 10106, 5, 66074, 20, 'MA', '1979-07-25', 'Divorced', '2013-01-07', '2014-03-31', 14.0, 'Production       ', 'Indeed', 'Fully Meets', 4.52, 3, 0, 20, 'Production Technician II', 'David Stanley', 'F', 'No', 'No', 'Asian', '1979-07-25', '2013-01-07', 1, 1, 1, 3, 0),
#  ('Langton, Enrico', 10052, 5, 46120, 19, 'MA', '1986-12-09', 'Married', '2012-07-09', None, 14.0, 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 5, 0, 13, 'Production Technician I', 'David Stanley', 'M ', 'No', 'No', 'White', '1986-12-09', '2012-07-09', 0, 11, 0, 3, 0),
#  ('LaRotonda, William  ', 10038, 1, 64520, 1, 'MA', '1984-04-26', 'Divorced', '2014-01-06', None, 1.0, 'Admin Offices', 'Website', 'Fully Meets', 5.0, 4, 4, 3, 'Accountant I', 'Brandon R. LeBlanc', 'M ', 'No', 'No', 'Black or African American', '1984-04-26', '2014-01-06', 0, 9, 1, 3, 0),
#  ('Latif, Mohammed', 10249, 5, 61962, 20, 'MA', '1984-05-09', 'Married', '2012-04-02', '2013-04-15', 20.0, 'Production       ', 'Google Search', 'Fully Meets', 4.9, 3, 0, 20, 'Production Technician II', 'Kissy Sullivan', 'M ', 'No', 'No', 'White', '1984-05-09', '2012-04-02', 1, 1, 0, 3, 0),
#  ('Le, Binh', 10232, 3, 81584, 22, 'MA', '1987-06-14', 'Single', '2016-10-02', None, 13.0, 'IT/IS', 'Indeed', 'Fully Meets', 4.1, 5, 7, 2, 'Senior BI Developer', 'Brian Champaigne', 'F', 'No', 'No', 'Asian', '1987-06-14', '2016-10-02', 0, 6, 1, 3, 0),
#  ('Leach, Dallas', 10087, 5, 63676, 19, 'MA', '1979-01-17', 'Single', '2011-09-26', '2018-08-19', 20.0, 'Production       ', 'CareerBuilder', 'Fully Meets', 4.88, 3, 0, 17, 'Production Technician I', 'Kissy Sullivan', 'F', 'No', 'No', 'Asian', '1979-01-17', '2011-09-26', 1, 6, 1, 3, 0),
#  ('LeBlanc, Brandon  R', 10134, 1, 93046, 24, 'MA', '1984-06-10', 'Married', '2016-01-05', None, 2.0, 'Admin Offices', 'CareerBuilder', 'Fully Meets', 4.1, 4, 0, 20, 'Software Engineer', 'Janet King', 'M ', 'No', 'No', 'White', '1984-06-10', '2016-01-05', 0, 7, 0, 3, 0),
#  ('Lecter, Hannibal', 10251, 5, 64738, 19, 'MA', '1982-09-02', 'Married', '2012-05-14', None, 16.0, 'Production       ', 'Google Search', 'Fully Meets', 4.1, 3, 0, 10, 'Production Technician I', 'Elijiah Gray', 'M ', 'No', 'No', 'Asian', '1982-09-02', '2012-05-14', 0, 11, 0, 3, 0),
#  ('Leruth, Giovanni', 10103, 6, 70468, 3, 'UT', '1988-12-27', 'Separated', '2012-04-30', None, 17.0, 'Sales', 'Website', 'Fully Meets', 4.53, 3, 0, 16, 'Area Sales Manager', 'John Smith', 'M ', 'No', 'No', 'Black or African American', '1988-12-27', '2012-04-30', 0, 11, None, 3, 0),
#  ('Liebig, Ketsia', 10017, 5, 77915, 18, 'MA', '1981-10-26', 'Married', '2013-09-30', None, 2.0, 'Production       ', 'Website', 'Exceeds', 4.1, 3, 0, 11, 'Production Manager', 'Janet King', 'F', 'No', 'No', 'White', '1981-10-26', '2013-09-30', 0, 9, 0, 4, 0),
#  ('Linares, Marilyn ', 10186, 5, 52624, 19, 'MA', '1981-03-26', 'Married', '2011-07-05', '2018-09-26', 22.0, 'Production       ', 'Indeed', 'Fully Meets', 3.18, 4, 0, 16, 'Production Technician I', 'Michael Albert', 'F', 'No', 'No', 'White', '1981-03-26', '2011-07-05', 1, 7, 0, 3, 0),
#  ('Linden, Mathew', 10137, 5, 63450, 20, 'MA', '1979-03-19', 'Married', '2013-07-08', None, 18.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.0, 3, 0, 7, 'Production Technician II', 'Kelley Spirea', 'M ', 'No', 'No', 'White', '1979-03-19', '2013-07-08', 0, 10, 0, 3, 0),
#  ('Lindsay, Leonara ', 10008, 3, 51777, 14, 'CT', '1988-10-05', 'Single', '2011-01-21', None, 6.0, 'IT/IS', 'Diversity Job Fair', 'Exceeds', 4.64, 4, 5, 14, 'IT Support', 'Eric Dougall', 'F', 'Yes', 'Yes', 'Black or African American', '1988-10-05', '2011-01-21', 0, 12, 1, 4, 1),
# ...
#  ('Simard, Kramer', 10178, 3, 87826, 9, 'MA', '1970-02-08', 'Married', '2015-01-05', None, 4.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 3.32, 3, 7, 16, 'Data Analyst', 'Simon Roup', 'M ', 'No', 'Yes', 'White', '1970-02-08', '2015-01-05', 0, 8, 0, 3, 0),
#  ('Singh, Nan ', 10039, 1, 51920, 2, 'MA', '1988-05-19', 'Single', '2015-05-01', None, 1.0, 'Admin Offices', 'Website', 'Fully Meets', 5.0, 3, 5, 2, 'Administrative Assistant', 'Brandon R. LeBlanc', 'F', 'No', 'No', 'White', '1988-05-19', '2015-05-01', 0, 8, 1, 3, 0),
#  ('Sloan, Constance', 10095, 5, 63878, 20, 'MA', '1987-11-25', 'Single', '2009-10-26', '2015-04-08', 22.0, 'Production       ', 'CareerBuilder', 'Fully Meets', 4.68, 4, 0, 20, 'Production Technician II', 'Michael Albert', 'F', 'No', 'No', 'White', '1987-11-25', '2009-10-26', 1, 5, 1, 3, 0),
#  ('Smith, Joe', 10027, 5, 60656, 20, 'MA', '1963-10-30', 'Single', '2014-09-29', None, 16.0, 'Production       ', 'Indeed', 'Exceeds', 4.3, 3, 0, 4, 'Production Technician II', 'Elijiah Gray', 'M ', 'No', 'No', 'White', '1963-10-30', '2014-09-29', 0, 8, 1, 4, 0),
#  ('Smith, John', 10291, 6, 72992, 21, 'MA', '1984-08-16', 'Divorced', '2014-05-18', None, 15.0, 'Sales', 'Diversity Job Fair', 'Needs Improvement', 2.4, 4, 0, 16, 'Sales Manager', 'Debra Houlihan', 'M ', 'Yes', 'No', 'Black or African American', '1984-08-16', '2014-05-18', 0, 9, 1, 2, 1),
#  ('Smith, Leigh Ann', 10153, 1, 55000, 2, 'MA', '1987-06-14', 'Married', '2011-09-26', '2013-09-25', 1.0, 'Admin Offices', 'Diversity Job Fair', 'Fully Meets', 3.8, 4, 4, 17, 'Administrative Assistant', 'Brandon R. LeBlanc', 'F', 'Yes', 'No', 'Black or African American', '1987-06-14', '2011-09-26', 1, 1, 0, 3, 1),
#  ('Smith, Sade', 10157, 5, 58939, 19, 'MA', '1965-02-02', 'Single', '2013-11-11', None, 19.0, 'Production       ', 'Employee Referral', 'Fully Meets', 3.73, 3, 0, 16, 'Production Technician I', 'Ketsia Liebig', 'F', 'No', 'No', 'White', '1965-02-02', '2013-11-11', 0, 9, 1, 3, 0),
#  ('Soto, Julia ', 10119, 3, 66593, 14, 'MA', '1973-03-12', 'Married', '2011-06-10', None, 6.0, 'IT/IS', 'LinkedIn', 'Fully Meets', 4.3, 3, 5, 19, 'IT Support', 'Eric Dougall', 'F', 'No', 'No', 'Black or African American', '1973-03-12', '2011-06-10', 0, 12, 0, 3, 0),
#  ('Soze, Keyser', 10180, 3, 87565, 28, 'MA', '1983-02-09', 'Married', '2016-06-30', None, 7.0, 'IT/IS', 'LinkedIn', 'Fully Meets', 3.27, 4, 5, 13, 'Sr. Network Engineer', 'Peter Monroe', 'M ', 'No', 'No', 'Asian', '1983-02-09', '2016-06-30', 0, 7, 0, 3, 0),
#  ('Sparks, Taylor  ', 10302, 5, 64021, 19, 'MA', '1968-07-20', 'Married', '2012-02-20', None, 12.0, 'Production       ', 'Indeed', 'PIP', 2.4, 2, 1, 20, 'Production Technician I', 'Brannon Miller', 'F', 'No', 'No', 'White', '1968-07-20', '2012-02-20', 0, 11, 0, 1, 0),
#  ('Spirea, Kelley', 10090, 5, 65714, 18, 'MA', '1975-09-30', 'Married', '2012-10-02', None, 2.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.83, 5, 0, 15, 'Production Manager', 'Janet King', 'F', 'No', 'No', 'White', '1975-09-30', '2012-10-02', 0, 10, 0, 3, 0),
#  ('Squatrito, Kristen', 10030, 5, 62425, 19, 'MA', '1973-03-26', 'Divorced', '2013-05-13', '2015-06-29', 14.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.1, 4, 0, 16, 'Production Technician I', 'David Stanley', 'F', 'No', 'No', 'White', '1973-03-26', '2013-05-13', 1, 2, 1, 4, 0),
#  ('Stanford,Barbara  M', 10278, 5, 47961, 19, 'MA', '1982-08-25', 'Divorced', '2011-01-10', None, 20.0, 'Production       ', 'Google Search', 'Fully Meets', 4.1, 4, 0, 9, 'Production Technician I', 'Kissy Sullivan', 'F', 'No', 'No', 'Two or more races', '1982-08-25', '2011-01-10', 0, 12, 1, 3, 0),
#  ('Stansfield, Norman', 10307, 6, 58273, 3, 'NV', '1974-05-09', 'Married', '2014-05-12', None, 21.0, 'Sales', 'Website', 'PIP', 1.81, 2, 0, 5, 'Area Sales Manager', 'Lynn Daneault', 'M ', 'No', 'No', 'White', '1974-05-09', '2014-05-12', 0, 9, 0, 1, 0),
#  ('Steans, Tyrone  ', 10147, 1, 63003, 1, 'MA', '1986-09-01', 'Single', '2014-09-29', None, 1.0, 'Admin Offices', 'Indeed', 'Fully Meets', 3.9, 5, 5, 9, 'Accountant I', 'Brandon R. LeBlanc', 'M ', 'No', 'No', 'White', '1986-09-01', '2014-09-29', 0, 8, 1, 3, 0),
#  ('Stoica, Rick', 10266, 5, 61355, 19, 'MA', '1985-03-14', 'Married', '2014-02-17', None, 18.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.7, 3, 0, 4, 'Production Technician I', 'Kelley Spirea', 'M ', 'No', 'No', 'Asian', '1985-03-14', '2014-02-17', 0, 9, 0, 3, 0),
#  ('Strong, Caitrin', 10241, 6, 60120, 3, 'MT', '1989-05-12', 'Married', '2010-09-27', None, 17.0, 'Sales', 'Indeed', 'Fully Meets', 4.1, 4, 0, 18, 'Area Sales Manager', 'John Smith', 'F', 'No', 'No', 'Black or African American', '1989-05-12', '2010-09-27', 0, 12, 0, 3, 0),
#  ('Sullivan, Kissy ', 10158, 5, 63682, 18, 'MA', '1978-03-28', 'Married', '2009-01-08', None, 2.0, 'Production       ', 'Indeed', 'Fully Meets', 3.73, 4, 0, 12, 'Production Manager', 'Janet King', 'F', 'No', 'No', 'Black or African American', '1978-03-28', '2009-01-08', 0, 14, 0, 3, 0),
#  ('Sullivan, Timothy', 10117, 5, 63025, 19, 'MA', '1982-10-07', 'Married', '2015-01-05', None, 22.0, 'Production       ', 'Google Search', 'Fully Meets', 4.36, 5, 0, 10, 'Production Technician I', 'Michael Albert', 'M ', 'No', 'Yes', 'White', '1982-10-07', '2015-01-05', 0, 8, 0, 3, 0),
#  ('Sutwell, Barbara', 10209, 5, 59238, 19, 'MA', '1968-08-15', 'Single', '2012-05-14', None, 16.0, 'Production       ', 'Indeed', 'Fully Meets', 3.4, 5, 0, 13, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'Asian', '1968-08-15', '2012-05-14', 0, 11, 1, 3, 0),
#  ('Szabo, Andrew', 10024, 4, 92989, 24, 'MA', '1983-05-06', 'Single', '2014-07-07', None, 10.0, 'Software Engineering', 'LinkedIn', 'Exceeds', 4.5, 5, 5, 1, 'Software Engineer', 'Alex Sweetwater', 'M ', 'No', 'No', 'White', '1983-05-06', '2014-07-07', 0, 9, 1, 4, 0),
#  ('Tannen, Biff', 10173, 3, 90100, 4, 'MA', '1987-10-24', 'Married', '2017-04-20', None, 13.0, 'IT/IS', 'Indeed', 'Fully Meets', 3.4, 3, 6, 14, 'BI Developer', 'Brian Champaigne', 'M ', 'No', 'No', 'White', '1987-10-24', '2017-04-20', 0, 6, 0, 3, 0),
#  ('Tavares, Desiree  ', 10221, 5, 60754, 19, 'MA', '1975-04-03', 'Married', '2009-04-27', '2013-04-01', 39.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.5, 5, 0, 11, 'Production Technician I', 'Webster Butler', 'F', 'Yes', 'No', 'Black or African American', '1975-04-03', '2009-04-27', 1, 3, 0, 3, 1),
#  ('Tejeda, Lenora ', 10146, 5, 72202, 20, 'MA', '1953-05-24', 'Married', '2011-05-16', '2017-07-08', 16.0, 'Production       ', 'Google Search', 'Fully Meets', 3.93, 3, 0, 3, 'Production Technician II', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1953-05-24', '2011-05-16', 1, 6, 0, 3, 0),
#  ('Terry, Sharlene ', 10161, 6, 58370, 3, 'OR', '1965-05-07', 'Single', '2014-09-29', None, 21.0, 'Sales', 'Indeed', 'Fully Meets', 3.69, 3, 0, 18, 'Area Sales Manager', 'Lynn Daneault', 'F', 'No', 'No', 'Black or African American', '1965-05-07', '2014-09-29', 0, 8, 1, 3, 0),
#  ('Theamstern, Sophia', 10141, 5, 48413, 19, 'MA', '1965-05-09', 'Single', '2011-07-05', '2016-09-05', 11.0, 'Production       ', 'Indeed', 'Fully Meets', 3.98, 4, 0, 1, 'Production Technician I', 'Amy Dunn', 'F', 'No', 'No', 'White', '1965-05-09', '2011-07-05', 1, 5, 1, 3, 0),
#  ('Thibaud, Kenneth', 10268, 5, 67176, 20, 'MA', '1975-09-16', 'Widowed', '2007-06-25', '2010-08-30', 39.0, 'Production       ', 'Other', 'Fully Meets', 4.1, 4, 0, 15, 'Production Technician II', 'Webster Butler', 'M ', 'No', 'No', 'White', '1975-09-16', '2007-06-25', 1, 3, 1, 3, 0),
#  ('Tippett, Jeanette', 10123, 5, 56339, 19, 'MA', '1967-06-05', 'Divorced', '2013-02-18', None, 12.0, 'Production       ', 'Indeed', 'Fully Meets', 4.21, 5, 0, 4, 'Production Technician I', 'Brannon Miller', 'F', 'No', 'No', 'Black or African American', '1967-06-05', '2013-02-18', 0, 10, 1, 3, 0),
#  ('Torrence, Jack', 10013, 6, 64397, 3, 'ND', '1968-01-15', 'Separated', '2006-01-09', None, 21.0, 'Sales', 'Indeed', 'Exceeds', 4.1, 3, 0, 6, 'Area Sales Manager', 'Lynn Daneault', 'M ', 'No', 'No', 'White', '1968-01-15', '2006-01-09', 0, 17, None, 4, 0),
#  ('Trang, Mei', 10287, 5, 63025, 19, 'MA', '1983-05-16', 'Single', '2014-02-17', None, 14.0, 'Production       ', 'LinkedIn', 'Needs Improvement', 2.44, 5, 0, 18, 'Production Technician I', 'David Stanley', 'F', 'No', 'No', 'White', '1983-05-16', '2014-02-17', 0, 9, 1, 2, 0),
#  ('Tredinnick, Neville ', 10044, 3, 75281, 15, 'MA', '1988-05-05', 'Married', '2015-01-05', '2016-02-12', 7.0, 'IT/IS', 'CareerBuilder', 'Fully Meets', 5.0, 3, 5, 11, 'Network Engineer', 'Peter Monroe', 'M ', 'No', 'No', 'White', '1988-05-05', '2015-01-05', 1, 1, 0, 3, 0),
#  ('True, Edward', 10102, 4, 100416, 24, 'MA', '1983-06-14', 'Single', '2013-02-18', '2018-04-15', 10.0, 'Software Engineering', 'Diversity Job Fair', 'Fully Meets', 4.6, 3, 4, 9, 'Software Engineer', 'Alex Sweetwater', 'M ', 'Yes', 'No', 'Black or African American', '1983-06-14', '2013-02-18', 1, 5, 1, 3, 1),
#  ('Trzeciak, Cybil', 10270, 5, 74813, 20, 'MA', '1985-03-15', 'Single', '2011-01-10', '2014-07-02', 11.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.4, 3, 0, 5, 'Production Technician II', 'Amy Dunn', 'F', 'No', 'No', 'White', '1985-03-15', '2011-01-10', 1, 3, 1, 3, 0),
#  ('Turpin, Jumil', 10045, 3, 76029, 15, 'MA', '1969-03-31', 'Married', '2015-03-30', None, 7.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 5.0, 4, 7, 8, 'Network Engineer', 'Peter Monroe', 'M ', 'No', 'No', 'White', '1969-03-31', '2015-03-30', 0, 8, 0, 3, 0),
#  ('Valentin,Jackie', 10205, 6, 57859, 3, 'AZ', '1991-05-23', 'Married', '2011-07-05', None, 17.0, 'Sales', 'Indeed', 'Fully Meets', 2.81, 3, 0, 16, 'Area Sales Manager', 'John Smith', 'F', 'No', 'No', 'Two or more races', '1991-05-23', '2011-07-05', 0, 12, 0, 3, 0),
#  ('Veera, Abdellah ', 10014, 5, 58523, 19, 'MA', '1987-01-31', 'Divorced', '2012-08-13', '2016-02-05', 20.0, 'Production       ', 'LinkedIn', 'Exceeds', 4.5, 5, 0, 15, 'Production Technician I', 'Kissy Sullivan', 'M ', 'No', 'No', 'White', '1987-01-31', '2012-08-13', 1, 3, 1, 4, 0),
#  ('Vega, Vincent', 10144, 5, 88976, 18, 'MA', '1968-10-10', 'Divorced', '2011-08-01', None, 2.0, 'Production       ', 'Employee Referral', 'Fully Meets', 3.93, 3, 0, 19, 'Production Manager', 'Janet King', 'M ', 'No', 'No', 'White', '1968-10-10', '2011-08-01', 0, 12, 1, 3, 0),
#  ('Villanueva, Noah', 10253, 6, 55875, 3, 'ME', '1989-07-11', 'Single', '2012-03-05', None, 17.0, 'Sales', 'Website', 'Fully Meets', 4.5, 4, 0, 11, 'Area Sales Manager', 'John Smith', 'M ', 'No', 'No', 'Asian', '1989-07-11', '2012-03-05', 0, 11, 1, 3, 0),
#  ('Voldemort, Lord', 10118, 3, 113999, 8, 'MA', '1986-08-07', 'Married', '2015-02-16', '2017-02-22', 4.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 4.33, 3, 7, 9, 'Database Administrator', 'Simon Roup', 'M ', 'No', 'No', 'Black or African American', '1986-08-07', '2015-02-16', 1, 2, 0, 3, 0),
#  ('Volk, Colleen', 10022, 5, 49773, 19, 'MA', '1986-06-03', 'Married', '2011-09-26', '2016-02-08', 18.0, 'Production       ', 'Google Search', 'Exceeds', 4.3, 5, 0, 18, 'Production Technician I', 'Kelley Spirea', 'F', 'No', 'No', 'White', '1986-06-03', '2011-09-26', 1, 4, 0, 4, 0),
#  ('Von Massenbach, Anna', 10183, 5, 62068, 19, 'MA', '1985-04-06', 'Single', '2015-07-05', None, 22.0, 'Production       ', 'LinkedIn', 'Fully Meets', 3.21, 3, 0, 7, 'Production Technician I', 'Michael Albert', 'F', 'No', 'No', 'White', '1985-04-06', '2015-07-05', 0, 8, 1, 3, 0),
#  ('Walker, Roger', 10190, 5, 66541, 20, 'MA', '1976-02-10', 'Single', '2014-08-18', None, 19.0, 'Production       ', 'Employee Referral', 'Fully Meets', 3.11, 5, 0, 4, 'Production Technician II', 'Ketsia Liebig', 'M ', 'No', 'No', 'Black or African American', '1976-02-10', '2014-08-18', 0, 9, 1, 3, 0),
#  ('Wallace, Courtney  E', 10274, 5, 80512, 18, 'MA', '1955-11-14', 'Married', '2011-09-26', '2012-01-02', 2.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.5, 3, 0, 5, 'Production Manager', 'Janet King', 'F', 'Yes', 'No', 'Black or African American', '1955-11-14', '2011-09-26', 1, 0, 0, 3, 1),
#  ('Wallace, Theresa', 10293, 5, 50274, 19, 'MA', '1980-08-02', 'Single', '2012-08-13', '2015-09-01', 16.0, 'Production       ', 'CareerBuilder', 'Needs Improvement', 2.5, 3, 0, 13, 'Production Technician I', 'Elijiah Gray', 'F', 'No', 'No', 'White', '1980-08-02', '2012-08-13', 1, 3, 1, 2, 0),
#  ('Wang, Charlie', 10172, 3, 84903, 22, 'MA', '1981-07-08', 'Single', '2017-02-15', None, 13.0, 'IT/IS', 'Indeed', 'Fully Meets', 3.42, 4, 7, 17, 'Senior BI Developer', 'Brian Champaigne', 'M ', 'No', 'No', 'Asian', '1981-07-08', '2017-02-15', 0, 6, 1, 3, 0),
#  ('Warfield, Sarah', 10127, 3, 107226, 28, 'MA', '1978-05-02', 'Widowed', '2015-03-30', None, 7.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 4.2, 4, 8, 7, 'Sr. Network Engineer', 'Peter Monroe', 'F', 'No', 'No', 'Asian', '1978-05-02', '2015-03-30', 0, 8, 1, 3, 0),
#  ('Whittier, Scott', 10072, 5, 58371, 19, 'MA', '1987-05-24', 'Single', '2011-01-10', '2014-05-15', 39.0, 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 5, 0, 11, 'Production Technician I', 'Webster Butler', 'M ', 'No', 'Yes', 'White', '1987-05-24', '2011-01-10', 1, 3, 1, 3, 0),
#  ('Wilber, Barry', 10048, 5, 55140, 19, 'MA', '1965-09-09', 'Married', '2011-05-16', '2015-09-07', 11.0, 'Production       ', 'Website', 'Fully Meets', 5.0, 3, 0, 7, 'Production Technician I', 'Amy Dunn', 'M ', 'No', 'No', 'White', '1965-09-09', '2011-05-16', 1, 4, 0, 3, 0),
#  ('Wilkes, Annie', 10204, 5, 58062, 19, 'MA', '1983-07-30', 'Divorced', '2011-01-10', '2012-05-14', 19.0, 'Production       ', 'Google Search', 'Fully Meets', 3.6, 5, 0, 9, 'Production Technician I', 'Ketsia Liebig', 'F', 'No', 'No', 'White', '1983-07-30', '2011-01-10', 1, 1, 1, 3, 0),
#  ('Williams, Jacquelyn  ', 10264, 5, 59728, 19, 'MA', '1969-10-02', 'Single', '2012-01-09', '2015-06-27', 19.0, 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.3, 4, 0, 16, 'Production Technician I', 'Ketsia Liebig', 'F', 'Yes', 'Yes', 'Black or African American', '1969-10-02', '2012-01-09', 1, 3, 1, 3, 1),
#  ('Winthrop, Jordan  ', 10033, 5, 70507, 20, 'MA', '1958-11-07', 'Single', '2013-01-07', '2016-02-21', 12.0, 'Production       ', 'LinkedIn', 'Exceeds', 5.0, 3, 0, 7, 'Production Technician II', 'Brannon Miller', 'M ', 'No', 'No', 'White', '1958-11-07', '2013-01-07', 1, 3, 1, 4, 0),
#  ('Wolk, Hang  T', 10174, 5, 60446, 20, 'MA', '1985-04-20', 'Single', '2014-09-29', None, 14.0, 'Production       ', 'LinkedIn', 'Fully Meets', 3.4, 4, 0, 14, 'Production Technician II', 'David Stanley', 'F', 'No', 'No', 'White', '1985-04-20', '2014-09-29', 0, 8, 1, 3, 0),
#  ('Woodson, Jason', 10135, 5, 65893, 20, 'MA', '1985-05-11', 'Single', '2014-07-07', None, 20.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.07, 4, 0, 13, 'Production Technician II', 'Kissy Sullivan', 'M ', 'No', 'No', 'White', '1985-05-11', '2014-07-07', 0, 9, 1, 3, 0),
#  ('Ybarra, Catherine ', 10301, 5, 48513, 19, 'MA', '1982-05-04', 'Single', '2008-09-02', '2015-09-29', 12.0, 'Production       ', 'Google Search', 'PIP', 3.2, 2, 0, 4, 'Production Technician I', 'Brannon Miller', 'F', 'No', 'No', 'Asian', '1982-05-04', '2008-09-02', 1, 7, 1, 1, 0),
#  ('Zamora, Jennifer', 10010, 3, 220450, 6, 'MA', '1979-08-30', 'Single', '2010-04-10', None, 2.0, 'IT/IS', 'Employee Referral', 'Exceeds', 4.6, 5, 6, 16, 'CIO', 'Janet King', 'F', 'No', 'No', 'White', '1979-08-30', '2010-04-10', 0, 13, 1, 4, 0),
#  ('Zhou, Julia', 10043, 3, 89292, 9, 'MA', '1979-02-24', 'Single', '2015-03-30', None, 4.0, 'IT/IS', 'Employee Referral', 'Fully Meets', 5.0, 3, 5, 11, 'Data Analyst', 'Simon Roup', 'F', 'No', 'No', 'White', '1979-02-24', '2015-03-30', 0, 8, 1, 3, 0),
#  ('Zima, Colleen', 10271, 5, 45046, 19, 'MA', '1978-08-17', 'Widowed', '2014-09-29', None, 14.0, 'Production       ', 'LinkedIn', 'Fully Meets', 4.5, 5, 0, 2, 'Production Technician I', 'David Stanley', 'F', 'No', 'No', 'Asian', '1978-08-17', '2014-09-29', 0, 8, 1, 3, 0)]

# %%
# %%sql
#
# CREATE TABLE HR_Datav1 AS
#
# SELECT
#     EmpID,
#     PerfScore_ID,
#     Salary,
#     date_term AS Fired,
#     EmpSatisfaction,
#     SpecialProjectsCount,
#     Absences
# FROM hr_dataset;
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
# []

# %%
# Query the hr_dataset table using the %sql magic command
result = %sql SELECT * FROM hr_datav1

# Convert the result to a DataFrame
df = result.DataFrame()

# Specify the CSV file path
csv_file_path = 'hr_datav1.csv'

# Export the DataFrame to a CSV file
df.to_csv(csv_file_path, index=False)
# Out:
#  * sqlite:///hr_data_databasee.db
# Done.
